# %% [markdown]
# # Sort and save pictures into folders per year

# %% [markdown]
# Start by updating file names - replace space by '_'

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/
# for f in 20*/*; do mv "$f" `echo $f | tr ' ' '_'`; done
# Out:
# mv: '2015/IMG_5038.JPG' and '2015/IMG_5038.JPG' are the same file
# mv: '2015/IMG_5051.PNG' and '2015/IMG_5051.PNG' are the same file
# mv: '2015/IMG_5735.JPG' and '2015/IMG_5735.JPG' are the same file
# mv: '2015/IMG_5775.JPG' and '2015/IMG_5775.JPG' are the same file
# mv: '2015/IMG_5845.JPG' and '2015/IMG_5845.JPG' are the same file
# mv: '2015/IMG_8248.JPG' and '2015/IMG_8248.JPG' are the same file
# mv: '2015/IMG_8413.JPG' and '2015/IMG_8413.JPG' are the same file
# mv: '2015/IMG_8434.JPG' and '2015/IMG_8434.JPG' are the same file
# mv: '2015/IMG_8435.JPG' and '2015/IMG_8435.JPG' are the same file
# mv: '2015/IMG_8444.JPG' and '2015/IMG_8444.JPG' are the same file
# mv: '2016/92f0684aaf20b8eae5d8bed69a3c5207.jpg' and '2016/92f0684aaf20b8eae5d8bed69a3c5207.jpg' are the same file
# mv: '2016/IMG_0058.PNG' and '2016/IMG_0058.PNG' are the same file
# mv: '2016/IMG_0474.JPG' and '2016/IMG_0474.JPG' are the same file
# mv: '2016/IMG_0657.PNG' and '2016/IMG_0657.PNG' are the same file
# mv: '2016/IMG_0663.PNG' and '2016/IMG_0663.PNG' are the same file
# mv: '2016/IMG_1321.JPG' and '2016/IMG_1321.JPG' are the same file
# mv: '2016/IMG_1322.JPG' and '2016/IMG_1322.JPG' are the same file
# mv: '2016/IMG_1324.PNG' and '2016/IMG_1324.PNG' are the same file
# mv: '2016/IMG_1370.JPG' and '2016/IMG_1370.JPG' are the same file
# mv: '2016/IMG_1380.JPG' and '2016/IMG_1380.JPG' are the same file
# mv: '2016/IMG_1396.JPG' and '2016/IMG_1396.JPG' are the same file
# mv: '2016/IMG_1405.JPG' and '2016/IMG_1405.JPG' are the same file
# mv: '2016/IMG_2128.PNG' and '2016/IMG_2128.PNG' are the same file
# mv: '2016/IMG_3603.PNG' and '2016/IMG_3603.PNG' are the same file
# mv: '2016/IMG_3604.PNG' and '2016/IMG_3604.PNG' are the same file
# mv: '2016/IMG_5388.JPG' and '2016/IMG_5388.JPG' are the same file
# mv: '2016/IMG_5510.JPG' and '2016/IMG_5510.JPG' are the same file
# mv: '2016/IMG_5599.PNG' and '2016/IMG_5599.PNG' are the same file
# mv: '2016/IMG_5614.jpg' and '2016/IMG_5614.jpg' are the same file
# mv: '2016/IMG_6362.JPG' and '2016/IMG_6362.JPG' are the same file
# mv: '2016/IMG_6568.PNG' and '2016/IMG_6568.PNG' are the same file
# mv: '2016/IMG_6756.JPG' and '2016/IMG_6756.JPG' are the same file
# mv: '2016/IMG_6759.JPG' and '2016/IMG_6759.JPG' are the same file
# mv: '2016/IMG_6780.JPG' and '2016/IMG_6780.JPG' are the same file
# mv: '2016/IMG_6785.JPG' and '2016/IMG_6785.JPG' are the same file
# mv: '2016/IMG_6800.JPG' and '2016/IMG_6800.JPG' are the same file
# mv: '2016/IMG_7177.JPG' and '2016/IMG_7177.JPG' are the same file
# mv: '2016/IMG_7473.JPG' and '2016/IMG_7473.JPG' are the same file
# mv: '2016/IMG_7538.JPG' and '2016/IMG_7538.JPG' are the same file
# mv: '2016/IMG_7556.JPG' and '2016/IMG_7556.JPG' are the same file
# mv: '2016/IMG_7557.JPG' and '2016/IMG_7557.JPG' are the same file
# mv: '2016/IMG_7573.JPG' and '2016/IMG_7573.JPG' are the same file
# mv: '2016/IMG_7585.JPG' and '2016/IMG_7585.JPG' are the same file
# mv: '2016/IMG_7589.JPG' and '2016/IMG_7589.JPG' are the same file
# mv: '2016/IMG_7591.JPG' and '2016/IMG_7591.JPG' are the same file
# mv: '2016/IMG_7593.JPG' and '2016/IMG_7593.JPG' are the same file
# mv: '2016/IMG_7594.JPG' and '2016/IMG_7594.JPG' are the same file
# mv: '2016/IMG_7602.JPG' and '2016/IMG_7602.JPG' are the same file
# mv: '2016/IMG_7605.JPG' and '2016/IMG_7605.JPG' are the same file
# mv: '2016/IMG_7608.JPG' and '2016/IMG_7608.JPG' are the same file
# mv: '2016/IMG_7612.JPG' and '2016/IMG_7612.JPG' are the same file
# mv: '2016/IMG_7613.JPG' and '2016/IMG_7613.JPG' are the same file
# mv: '2016/IMG_7620.JPG' and '2016/IMG_7620.JPG' are the same file
# mv: '2016/IMG_7638.JPG' and '2016/IMG_7638.JPG' are the same file
# mv: '2016/IMG_7641.JPG' and '2016/IMG_7641.JPG' are the same file
# mv: '2016/IMG_7642.JPG' and '2016/IMG_7642.JPG' are the same file
# mv: '2016/IMG_7653.JPG' and '2016/IMG_7653.JPG' are the same file
# mv: '2016/IMG_7654.JPG' and '2016/IMG_7654.JPG' are the same file
# mv: '2016/IMG_7672.JPG' and '2016/IMG_7672.JPG' are the same file
# mv: '2016/IMG_7679.JPG' and '2016/IMG_7679.JPG' are the same file
# mv: '2016/IMG_7682.JPG' and '2016/IMG_7682.JPG' are the same file
# mv: '2016/IMG_7683.JPG' and '2016/IMG_7683.JPG' are the same file
# mv: '2016/IMG_7684.JPG' and '2016/IMG_7684.JPG' are the same file
# mv: '2016/IMG_7686.JPG' and '2016/IMG_7686.JPG' are the same file
# mv: '2016/IMG_7689.JPG' and '2016/IMG_7689.JPG' are the same file
# mv: '2016/IMG_7690.JPG' and '2016/IMG_7690.JPG' are the same file
# mv: '2016/IMG_7707.JPG' and '2016/IMG_7707.JPG' are the same file
# mv: '2016/IMG_7708.JPG' and '2016/IMG_7708.JPG' are the same file
# mv: '2016/IMG_7712.JPG' and '2016/IMG_7712.JPG' are the same file
# mv: '2016/IMG_7715.JPG' and '2016/IMG_7715.JPG' are the same file
# mv: '2016/IMG_7721.JPG' and '2016/IMG_7721.JPG' are the same file
# mv: '2016/IMG_7722.JPG' and '2016/IMG_7722.JPG' are the same file
# mv: '2016/IMG_7723.JPG' and '2016/IMG_7723.JPG' are the same file
# mv: '2016/IMG_7725.JPG' and '2016/IMG_7725.JPG' are the same file
# mv: '2016/IMG_7729.JPG' and '2016/IMG_7729.JPG' are the same file
# mv: '2016/IMG_7730.JPG' and '2016/IMG_7730.JPG' are the same file
# mv: '2016/IMG_7775.JPG' and '2016/IMG_7775.JPG' are the same file
# mv: '2016/IMG_7787.JPG' and '2016/IMG_7787.JPG' are the same file
# mv: '2016/IMG_7872.JPG' and '2016/IMG_7872.JPG' are the same file
# mv: '2016/IMG_8131.JPG' and '2016/IMG_8131.JPG' are the same file
# mv: '2016/IMG_8174.JPG' and '2016/IMG_8174.JPG' are the same file
# mv: '2016/IMG_8195.PNG' and '2016/IMG_8195.PNG' are the same file
# mv: '2016/IMG_8212.JPG' and '2016/IMG_8212.JPG' are the same file
# mv: '2016/IMG_8315.PNG' and '2016/IMG_8315.PNG' are the same file
# mv: '2016/IMG_8323.JPG' and '2016/IMG_8323.JPG' are the same file
# mv: '2016/IMG_8324.JPG' and '2016/IMG_8324.JPG' are the same file
# mv: '2016/IMG_8334.JPG' and '2016/IMG_8334.JPG' are the same file
# mv: '2016/IMG_8343.JPG' and '2016/IMG_8343.JPG' are the same file
# mv: '2016/IMG_8344.JPG' and '2016/IMG_8344.JPG' are the same file
# mv: '2016/IMG_8345.JPG' and '2016/IMG_8345.JPG' are the same file
# mv: '2016/IMG_8346.JPG' and '2016/IMG_8346.JPG' are the same file
# mv: '2016/IMG_8349.JPG' and '2016/IMG_8349.JPG' are the same file
# mv: '2016/IMG_8350.JPG' and '2016/IMG_8350.JPG' are the same file
# mv: '2016/IMG_8378.JPG' and '2016/IMG_8378.JPG' are the same file
# mv: '2016/IMG_8474.JPG' and '2016/IMG_8474.JPG' are the same file
# mv: '2016/IMG_8475.JPG' and '2016/IMG_8475.JPG' are the same file
# mv: '2016/IMG_8477.JPG' and '2016/IMG_8477.JPG' are the same file
# mv: '2016/IMG_8543.PNG' and '2016/IMG_8543.PNG' are the same file
# mv: '2016/IMG_8555.JPG' and '2016/IMG_8555.JPG' are the same file
# mv: '2016/IMG_8568.JPG' and '2016/IMG_8568.JPG' are the same file
# mv: '2016/IMG_8630.JPG' and '2016/IMG_8630.JPG' are the same file
# mv: '2016/IMG_8653.JPG' and '2016/IMG_8653.JPG' are the same file
# mv: '2016/IMG_8684.JPG' and '2016/IMG_8684.JPG' are the same file
# mv: '2016/IMG_8703.JPG' and '2016/IMG_8703.JPG' are the same file
# mv: '2016/IMG_8705.JPG' and '2016/IMG_8705.JPG' are the same file
# mv: '2016/IMG_8766.JPG' and '2016/IMG_8766.JPG' are the same file
# mv: '2016/IMG_8774.JPG' and '2016/IMG_8774.JPG' are the same file
# mv: '2016/IMG_8912.JPG' and '2016/IMG_8912.JPG' are the same file
# mv: '2016/IMG_9003.JPG' and '2016/IMG_9003.JPG' are the same file
# mv: '2016/IMG_9188.JPG' and '2016/IMG_9188.JPG' are the same file
# mv: '2016/IMG_9190.JPG' and '2016/IMG_9190.JPG' are the same file
# mv: '2016/IMG_9192.JPG' and '2016/IMG_9192.JPG' are the same file
# mv: '2016/IMG_9239.JPG' and '2016/IMG_9239.JPG' are the same file
# mv: '2016/IMG_9401.JPG' and '2016/IMG_9401.JPG' are the same file
# mv: '2016/IMG_9424.JPG' and '2016/IMG_9424.JPG' are the same file
# mv: '2016/IMG_9455.JPG' and '2016/IMG_9455.JPG' are the same file
# mv: '2016/IMG_9498.JPG' and '2016/IMG_9498.JPG' are the same file
# mv: '2016/IMG_9527.JPG' and '2016/IMG_9527.JPG' are the same file
# mv: '2016/IMG_9546.JPG' and '2016/IMG_9546.JPG' are the same file
# mv: '2016/IMG_9675.JPG' and '2016/IMG_9675.JPG' are the same file
# mv: '2016/IMG_9689.JPG' and '2016/IMG_9689.JPG' are the same file
# mv: cannot move '2016/Videos' to a subdirectory of itself, '2016/Videos/Videos'
# mv: '2016/a3f48d33ec5f648617f862e237427e6f.jpg' and '2016/a3f48d33ec5f648617f862e237427e6f.jpg' are the same file
# mv: '2016/cc748d060f16550df69be72053099bb5.jpg' and '2016/cc748d060f16550df69be72053099bb5.jpg' are the same file
# mv: '2017/08c76d32-8406-47b3-98c0-72b7b3d110ca.jpg' and '2017/08c76d32-8406-47b3-98c0-72b7b3d110ca.jpg' are the same file
# mv: '2017/0a9a2b88-ca53-459d-a39f-5e58532e3462.jpg' and '2017/0a9a2b88-ca53-459d-a39f-5e58532e3462.jpg' are the same file
# mv: '2017/1b0a5a97-ac5d-4510-b7a3-882d30c4a4e8.jpg' and '2017/1b0a5a97-ac5d-4510-b7a3-882d30c4a4e8.jpg' are the same file
# mv: '2017/1f268075-d8e3-411a-a700-27f93d6f98d8.jpg' and '2017/1f268075-d8e3-411a-a700-27f93d6f98d8.jpg' are the same file
# mv: '2017/2328d055-a7a8-402a-aea7-5da0b99e0212.jpg' and '2017/2328d055-a7a8-402a-aea7-5da0b99e0212.jpg' are the same file
# mv: '2017/340a6903-41d7-4cd2-bc27-f51cf540f6c1.jpg' and '2017/340a6903-41d7-4cd2-bc27-f51cf540f6c1.jpg' are the same file
# mv: '2017/3b152e28-6c94-4c93-a779-788ad9522468.jpg' and '2017/3b152e28-6c94-4c93-a779-788ad9522468.jpg' are the same file
# mv: '2017/3d1cceff-f2ca-49d8-bec2-390443fee568.jpg' and '2017/3d1cceff-f2ca-49d8-bec2-390443fee568.jpg' are the same file
# mv: '2017/3ddb4a68-ae73-42ff-9313-236d72fb41f0.jpg' and '2017/3ddb4a68-ae73-42ff-9313-236d72fb41f0.jpg' are the same file
# mv: '2017/42dd4a7d-545c-4bcc-bf64-ba2304915e1c.jpg' and '2017/42dd4a7d-545c-4bcc-bf64-ba2304915e1c.jpg' are the same file
# mv: '2017/4bcc3ade-103f-4515-bac7-fab94d827a77.jpg' and '2017/4bcc3ade-103f-4515-bac7-fab94d827a77.jpg' are the same file
# mv: '2017/4ccb79d5-1331-46f6-b71e-eb5af85b841a.jpg' and '2017/4ccb79d5-1331-46f6-b71e-eb5af85b841a.jpg' are the same file
# mv: '2017/5059508d-99d2-4733-a3df-baa2d5403355.jpg' and '2017/5059508d-99d2-4733-a3df-baa2d5403355.jpg' are the same file
# mv: '2017/57ddf6c3-7c24-42fc-a855-53f4e15c1fa1.jpg' and '2017/57ddf6c3-7c24-42fc-a855-53f4e15c1fa1.jpg' are the same file
# mv: '2017/5b40020b-2a32-417b-8c85-9a967150aba5.jpg' and '2017/5b40020b-2a32-417b-8c85-9a967150aba5.jpg' are the same file
# mv: '2017/6d681b18-5c51-4ba0-9aad-6006c5df060f.jpg' and '2017/6d681b18-5c51-4ba0-9aad-6006c5df060f.jpg' are the same file
# mv: '2017/719fb02c-07ad-4e6a-ba91-e936f4c73961.jpg' and '2017/719fb02c-07ad-4e6a-ba91-e936f4c73961.jpg' are the same file
# mv: '2017/7279e2d6-0e30-4f9c-99f3-f37cb9b27355.jpg' and '2017/7279e2d6-0e30-4f9c-99f3-f37cb9b27355.jpg' are the same file
# mv: '2017/7bdaa26c-4873-48f6-8fa1-4da4c4c5ca04.jpg' and '2017/7bdaa26c-4873-48f6-8fa1-4da4c4c5ca04.jpg' are the same file
# mv: '2017/856d7f71-e331-4862-9d55-4ab3f03949f4.jpg' and '2017/856d7f71-e331-4862-9d55-4ab3f03949f4.jpg' are the same file
# mv: '2017/99c69bf3-94e2-465d-8862-942a09737194.jpg' and '2017/99c69bf3-94e2-465d-8862-942a09737194.jpg' are the same file
# mv: '2017/IMG_0025.PNG' and '2017/IMG_0025.PNG' are the same file
# mv: '2017/IMG_0098.JPG' and '2017/IMG_0098.JPG' are the same file
# mv: '2017/IMG_0134.JPG' and '2017/IMG_0134.JPG' are the same file
# mv: '2017/IMG_0141.JPG' and '2017/IMG_0141.JPG' are the same file
# mv: '2017/IMG_0142.JPG' and '2017/IMG_0142.JPG' are the same file
# mv: '2017/IMG_0143.JPG' and '2017/IMG_0143.JPG' are the same file
# mv: '2017/IMG_0184.JPG' and '2017/IMG_0184.JPG' are the same file
# mv: '2017/IMG_0226.JPG' and '2017/IMG_0226.JPG' are the same file
# mv: '2017/IMG_0227.JPG' and '2017/IMG_0227.JPG' are the same file
# mv: '2017/IMG_0238.JPG' and '2017/IMG_0238.JPG' are the same file
# mv: '2017/IMG_0239.JPG' and '2017/IMG_0239.JPG' are the same file
# mv: '2017/IMG_0240.JPG' and '2017/IMG_0240.JPG' are the same file
# mv: '2017/IMG_0241.JPG' and '2017/IMG_0241.JPG' are the same file
# mv: '2017/IMG_0242.JPG' and '2017/IMG_0242.JPG' are the same file
# mv: '2017/IMG_0244.JPG' and '2017/IMG_0244.JPG' are the same file
# mv: '2017/IMG_0245.JPG' and '2017/IMG_0245.JPG' are the same file
# mv: '2017/IMG_0246.JPG' and '2017/IMG_0246.JPG' are the same file
# mv: '2017/IMG_0247.JPG' and '2017/IMG_0247.JPG' are the same file
# mv: '2017/IMG_0248.JPG' and '2017/IMG_0248.JPG' are the same file
# mv: '2017/IMG_0271.JPG' and '2017/IMG_0271.JPG' are the same file
# mv: '2017/IMG_0292.JPG' and '2017/IMG_0292.JPG' are the same file
# mv: '2017/IMG_0305.JPG' and '2017/IMG_0305.JPG' are the same file
# mv: '2017/IMG_0306.JPG' and '2017/IMG_0306.JPG' are the same file
# mv: '2017/IMG_0307.JPG' and '2017/IMG_0307.JPG' are the same file
# mv: '2017/IMG_0309.JPG' and '2017/IMG_0309.JPG' are the same file
# mv: '2017/IMG_0310.JPG' and '2017/IMG_0310.JPG' are the same file
# mv: '2017/IMG_0311.JPG' and '2017/IMG_0311.JPG' are the same file
# mv: '2017/IMG_0312.JPG' and '2017/IMG_0312.JPG' are the same file
# mv: '2017/IMG_0313.JPG' and '2017/IMG_0313.JPG' are the same file
# mv: '2017/IMG_0315(1).JPG' and '2017/IMG_0315(1).JPG' are the same file
# mv: '2017/IMG_0315.JPG' and '2017/IMG_0315.JPG' are the same file
# mv: '2017/IMG_0316(1).JPG' and '2017/IMG_0316(1).JPG' are the same file
# mv: '2017/IMG_0316.JPG' and '2017/IMG_0316.JPG' are the same file
# mv: '2017/IMG_0317.JPG' and '2017/IMG_0317.JPG' are the same file
# mv: '2017/IMG_0404.JPG' and '2017/IMG_0404.JPG' are the same file
# mv: '2017/IMG_0429.PNG' and '2017/IMG_0429.PNG' are the same file
# mv: '2017/IMG_0430.JPG' and '2017/IMG_0430.JPG' are the same file
# mv: '2017/IMG_0441.JPG' and '2017/IMG_0441.JPG' are the same file
# mv: '2017/IMG_0479.JPG' and '2017/IMG_0479.JPG' are the same file
# mv: '2017/IMG_0491.PNG' and '2017/IMG_0491.PNG' are the same file
# mv: '2017/IMG_0492.PNG' and '2017/IMG_0492.PNG' are the same file
# mv: '2017/IMG_0493.JPG' and '2017/IMG_0493.JPG' are the same file
# mv: '2017/IMG_0493.PNG' and '2017/IMG_0493.PNG' are the same file
# mv: '2017/IMG_0494.JPG' and '2017/IMG_0494.JPG' are the same file
# mv: '2017/IMG_0495.JPG' and '2017/IMG_0495.JPG' are the same file
# mv: '2017/IMG_0496.JPG' and '2017/IMG_0496.JPG' are the same file
# mv: '2017/IMG_0497.JPG' and '2017/IMG_0497.JPG' are the same file
# mv: '2017/IMG_0498.JPG' and '2017/IMG_0498.JPG' are the same file
# mv: '2017/IMG_0527.JPG' and '2017/IMG_0527.JPG' are the same file
# mv: '2017/IMG_0531.JPG' and '2017/IMG_0531.JPG' are the same file
# mv: '2017/IMG_0553.JPG' and '2017/IMG_0553.JPG' are the same file
# mv: '2017/IMG_0557.JPG' and '2017/IMG_0557.JPG' are the same file
# mv: '2017/IMG_0566.JPG' and '2017/IMG_0566.JPG' are the same file
# mv: '2017/IMG_0573.JPG' and '2017/IMG_0573.JPG' are the same file
# mv: '2017/IMG_0579.JPG' and '2017/IMG_0579.JPG' are the same file
# mv: '2017/IMG_0581.JPG' and '2017/IMG_0581.JPG' are the same file
# mv: '2017/IMG_0590.JPG' and '2017/IMG_0590.JPG' are the same file
# mv: '2017/IMG_0591.JPG' and '2017/IMG_0591.JPG' are the same file
# mv: '2017/IMG_0630.JPG' and '2017/IMG_0630.JPG' are the same file
# mv: '2017/IMG_0697(1).PNG' and '2017/IMG_0697(1).PNG' are the same file
# mv: '2017/IMG_0698.PNG' and '2017/IMG_0698.PNG' are the same file
# mv: '2017/IMG_0815.JPG' and '2017/IMG_0815.JPG' are the same file
# mv: '2017/IMG_0816.JPG' and '2017/IMG_0816.JPG' are the same file
# mv: '2017/IMG_0817.JPG' and '2017/IMG_0817.JPG' are the same file
# mv: '2017/IMG_0818(1).JPG' and '2017/IMG_0818(1).JPG' are the same file
# mv: '2017/IMG_0818.JPG' and '2017/IMG_0818.JPG' are the same file
# mv: '2017/IMG_0822.JPG' and '2017/IMG_0822.JPG' are the same file
# mv: '2017/IMG_0830.JPG' and '2017/IMG_0830.JPG' are the same file
# mv: '2017/IMG_0831.JPG' and '2017/IMG_0831.JPG' are the same file
# mv: '2017/IMG_0832.JPG' and '2017/IMG_0832.JPG' are the same file
# mv: '2017/IMG_0833.JPG' and '2017/IMG_0833.JPG' are the same file
# mv: '2017/IMG_0834.JPG' and '2017/IMG_0834.JPG' are the same file
# mv: '2017/IMG_0835.JPG' and '2017/IMG_0835.JPG' are the same file
# mv: '2017/IMG_0842.JPG' and '2017/IMG_0842.JPG' are the same file
# mv: '2017/IMG_0843.JPG' and '2017/IMG_0843.JPG' are the same file
# mv: '2017/IMG_0851.JPG' and '2017/IMG_0851.JPG' are the same file
# mv: '2017/IMG_0852.JPG' and '2017/IMG_0852.JPG' are the same file
# mv: '2017/IMG_0853.JPG' and '2017/IMG_0853.JPG' are the same file
# mv: '2017/IMG_0854.JPG' and '2017/IMG_0854.JPG' are the same file
# mv: '2017/IMG_0858(1).JPG' and '2017/IMG_0858(1).JPG' are the same file
# mv: '2017/IMG_0860(1).JPG' and '2017/IMG_0860(1).JPG' are the same file
# mv: '2017/IMG_0869.jpg' and '2017/IMG_0869.jpg' are the same file
# mv: '2017/IMG_0877.JPG' and '2017/IMG_0877.JPG' are the same file
# mv: '2017/IMG_0893.JPG' and '2017/IMG_0893.JPG' are the same file
# mv: '2017/IMG_0894.JPG' and '2017/IMG_0894.JPG' are the same file
# mv: '2017/IMG_0895.JPG' and '2017/IMG_0895.JPG' are the same file
# mv: '2017/IMG_0896.JPG' and '2017/IMG_0896.JPG' are the same file
# mv: '2017/IMG_0905.JPG' and '2017/IMG_0905.JPG' are the same file
# mv: '2017/IMG_0906.JPG' and '2017/IMG_0906.JPG' are the same file
# mv: '2017/IMG_0907.JPG' and '2017/IMG_0907.JPG' are the same file
# mv: '2017/IMG_0929.JPG' and '2017/IMG_0929.JPG' are the same file
# mv: '2017/IMG_1110.JPG' and '2017/IMG_1110.JPG' are the same file
# mv: '2017/IMG_1111.JPG' and '2017/IMG_1111.JPG' are the same file
# mv: '2017/IMG_1112.JPG' and '2017/IMG_1112.JPG' are the same file
# mv: '2017/IMG_1113.JPG' and '2017/IMG_1113.JPG' are the same file
# mv: '2017/IMG_1114.JPG' and '2017/IMG_1114.JPG' are the same file
# mv: '2017/IMG_1115.JPG' and '2017/IMG_1115.JPG' are the same file
# mv: '2017/IMG_1122.JPG' and '2017/IMG_1122.JPG' are the same file
# mv: '2017/IMG_1124.JPG' and '2017/IMG_1124.JPG' are the same file
# mv: '2017/IMG_1125.JPG' and '2017/IMG_1125.JPG' are the same file
# mv: '2017/IMG_1127.JPG' and '2017/IMG_1127.JPG' are the same file
# mv: '2017/IMG_1199.JPG' and '2017/IMG_1199.JPG' are the same file
# mv: '2017/IMG_1228.JPG' and '2017/IMG_1228.JPG' are the same file
# mv: '2017/IMG_1229.JPG' and '2017/IMG_1229.JPG' are the same file
# mv: '2017/IMG_1230.JPG' and '2017/IMG_1230.JPG' are the same file
# mv: '2017/IMG_1231.JPG' and '2017/IMG_1231.JPG' are the same file
# mv: '2017/IMG_1232.JPG' and '2017/IMG_1232.JPG' are the same file
# mv: '2017/IMG_1233.JPG' and '2017/IMG_1233.JPG' are the same file
# mv: '2017/IMG_1243.PNG' and '2017/IMG_1243.PNG' are the same file
# mv: '2017/IMG_1244.PNG' and '2017/IMG_1244.PNG' are the same file
# mv: '2017/IMG_1273.JPG' and '2017/IMG_1273.JPG' are the same file
# mv: '2017/IMG_1326.PNG' and '2017/IMG_1326.PNG' are the same file
# mv: '2017/IMG_1365.JPG' and '2017/IMG_1365.JPG' are the same file
# mv: '2017/IMG_1371.JPG' and '2017/IMG_1371.JPG' are the same file
# mv: '2017/IMG_1372.JPG' and '2017/IMG_1372.JPG' are the same file
# mv: '2017/IMG_1377.JPG' and '2017/IMG_1377.JPG' are the same file
# mv: '2017/IMG_1738.JPG' and '2017/IMG_1738.JPG' are the same file
# mv: '2017/IMG_1740.JPG' and '2017/IMG_1740.JPG' are the same file
# mv: '2017/IMG_1742.JPG' and '2017/IMG_1742.JPG' are the same file
# mv: '2017/IMG_1744.JPG' and '2017/IMG_1744.JPG' are the same file
# mv: '2017/IMG_1747.JPG' and '2017/IMG_1747.JPG' are the same file
# mv: '2017/IMG_1829.JPG' and '2017/IMG_1829.JPG' are the same file
# mv: '2017/IMG_2091.PNG' and '2017/IMG_2091.PNG' are the same file
# mv: '2017/IMG_2149.JPG' and '2017/IMG_2149.JPG' are the same file
# mv: '2017/IMG_2152.JPG' and '2017/IMG_2152.JPG' are the same file
# mv: '2017/IMG_2153.JPG' and '2017/IMG_2153.JPG' are the same file
# mv: '2017/IMG_2156.JPG' and '2017/IMG_2156.JPG' are the same file
# mv: '2017/IMG_2157.JPG' and '2017/IMG_2157.JPG' are the same file
# mv: '2017/IMG_2158.JPG' and '2017/IMG_2158.JPG' are the same file
# mv: '2017/IMG_2290.JPG' and '2017/IMG_2290.JPG' are the same file
# mv: '2017/IMG_2358.JPG' and '2017/IMG_2358.JPG' are the same file
# mv: '2017/IMG_2359.JPG' and '2017/IMG_2359.JPG' are the same file
# mv: '2017/IMG_2360.JPG' and '2017/IMG_2360.JPG' are the same file
# mv: '2017/IMG_2366.JPG' and '2017/IMG_2366.JPG' are the same file
# mv: '2017/IMG_2374.JPG' and '2017/IMG_2374.JPG' are the same file
# mv: '2017/IMG_2375.JPG' and '2017/IMG_2375.JPG' are the same file
# mv: '2017/IMG_2394.JPG' and '2017/IMG_2394.JPG' are the same file
# mv: '2017/IMG_2395.JPG' and '2017/IMG_2395.JPG' are the same file
# mv: '2017/IMG_2396.JPG' and '2017/IMG_2396.JPG' are the same file
# mv: '2017/IMG_2397.JPG' and '2017/IMG_2397.JPG' are the same file
# mv: '2017/IMG_2398.JPG' and '2017/IMG_2398.JPG' are the same file
# mv: '2017/IMG_2399.JPG' and '2017/IMG_2399.JPG' are the same file
# mv: '2017/IMG_2417.JPG' and '2017/IMG_2417.JPG' are the same file
# mv: '2017/IMG_2423.JPG' and '2017/IMG_2423.JPG' are the same file
# mv: '2017/IMG_2493.JPG' and '2017/IMG_2493.JPG' are the same file
# mv: '2017/IMG_2494.JPG' and '2017/IMG_2494.JPG' are the same file
# mv: '2017/IMG_2498.JPG' and '2017/IMG_2498.JPG' are the same file
# mv: '2017/IMG_2499.JPG' and '2017/IMG_2499.JPG' are the same file
# mv: '2017/IMG_2501.JPG' and '2017/IMG_2501.JPG' are the same file
# mv: '2017/IMG_2518.JPG' and '2017/IMG_2518.JPG' are the same file
# mv: '2017/IMG_2524.JPG' and '2017/IMG_2524.JPG' are the same file
# mv: '2017/IMG_2537.JPG' and '2017/IMG_2537.JPG' are the same file
# mv: '2017/IMG_2548.JPG' and '2017/IMG_2548.JPG' are the same file
# mv: '2017/IMG_2551.JPG' and '2017/IMG_2551.JPG' are the same file
# mv: '2017/IMG_2556.JPG' and '2017/IMG_2556.JPG' are the same file
# mv: '2017/IMG_2558.JPG' and '2017/IMG_2558.JPG' are the same file
# mv: '2017/IMG_2563.JPG' and '2017/IMG_2563.JPG' are the same file
# mv: '2017/IMG_2564.JPG' and '2017/IMG_2564.JPG' are the same file
# mv: '2017/IMG_2567.JPG' and '2017/IMG_2567.JPG' are the same file
# mv: '2017/IMG_2591.JPG' and '2017/IMG_2591.JPG' are the same file
# mv: '2017/IMG_2592.JPG' and '2017/IMG_2592.JPG' are the same file
# mv: '2017/IMG_2593.JPG' and '2017/IMG_2593.JPG' are the same file
# mv: '2017/IMG_2594.JPG' and '2017/IMG_2594.JPG' are the same file
# mv: '2017/IMG_2595.JPG' and '2017/IMG_2595.JPG' are the same file
# mv: '2017/IMG_2596.JPG' and '2017/IMG_2596.JPG' are the same file
# mv: '2017/IMG_2597.JPG' and '2017/IMG_2597.JPG' are the same file
# mv: '2017/IMG_2603.JPG' and '2017/IMG_2603.JPG' are the same file
# mv: '2017/IMG_2605.JPG' and '2017/IMG_2605.JPG' are the same file
# mv: '2017/IMG_2606.JPG' and '2017/IMG_2606.JPG' are the same file
# mv: '2017/IMG_2607.JPG' and '2017/IMG_2607.JPG' are the same file
# mv: '2017/IMG_2608.JPG' and '2017/IMG_2608.JPG' are the same file
# mv: '2017/IMG_2669.PNG' and '2017/IMG_2669.PNG' are the same file
# mv: '2017/IMG_2763.JPG' and '2017/IMG_2763.JPG' are the same file
# mv: '2017/IMG_2867.JPG' and '2017/IMG_2867.JPG' are the same file
# mv: '2017/IMG_2887.JPG' and '2017/IMG_2887.JPG' are the same file
# mv: '2017/IMG_2888.JPG' and '2017/IMG_2888.JPG' are the same file
# mv: '2017/IMG_2889.JPG' and '2017/IMG_2889.JPG' are the same file
# mv: '2017/IMG_2891.JPG' and '2017/IMG_2891.JPG' are the same file
# mv: '2017/IMG_2917.JPG' and '2017/IMG_2917.JPG' are the same file
# mv: '2017/IMG_2919.JPG' and '2017/IMG_2919.JPG' are the same file
# mv: '2017/IMG_2920.JPG' and '2017/IMG_2920.JPG' are the same file
# mv: '2017/IMG_2923.JPG' and '2017/IMG_2923.JPG' are the same file
# mv: '2017/IMG_2924.JPG' and '2017/IMG_2924.JPG' are the same file
# mv: '2017/IMG_2925.JPG' and '2017/IMG_2925.JPG' are the same file
# mv: '2017/IMG_2926.JPG' and '2017/IMG_2926.JPG' are the same file
# mv: '2017/IMG_2930.JPG' and '2017/IMG_2930.JPG' are the same file
# mv: '2017/IMG_2931.JPG' and '2017/IMG_2931.JPG' are the same file
# mv: '2017/IMG_2933.JPG' and '2017/IMG_2933.JPG' are the same file
# mv: '2017/IMG_2940.JPG' and '2017/IMG_2940.JPG' are the same file
# mv: '2017/IMG_2942.JPG' and '2017/IMG_2942.JPG' are the same file
# mv: '2017/IMG_2943.JPG' and '2017/IMG_2943.JPG' are the same file
# mv: '2017/IMG_2959.JPG' and '2017/IMG_2959.JPG' are the same file
# mv: '2017/IMG_2971.JPG' and '2017/IMG_2971.JPG' are the same file
# mv: '2017/IMG_2973.JPG' and '2017/IMG_2973.JPG' are the same file
# mv: '2017/IMG_2974.JPG' and '2017/IMG_2974.JPG' are the same file
# mv: '2017/IMG_2975.JPG' and '2017/IMG_2975.JPG' are the same file
# mv: '2017/IMG_3076.JPG' and '2017/IMG_3076.JPG' are the same file
# mv: '2017/IMG_3077.JPG' and '2017/IMG_3077.JPG' are the same file
# mv: '2017/IMG_3078.JPG' and '2017/IMG_3078.JPG' are the same file
# mv: '2017/IMG_3079.JPG' and '2017/IMG_3079.JPG' are the same file
# mv: '2017/IMG_3080.JPG' and '2017/IMG_3080.JPG' are the same file
# mv: '2017/IMG_3081.JPG' and '2017/IMG_3081.JPG' are the same file
# mv: '2017/IMG_3083.JPG' and '2017/IMG_3083.JPG' are the same file
# mv: '2017/IMG_3084.JPG' and '2017/IMG_3084.JPG' are the same file
# mv: '2017/IMG_3085.JPG' and '2017/IMG_3085.JPG' are the same file
# mv: '2017/IMG_3086.JPG' and '2017/IMG_3086.JPG' are the same file
# mv: '2017/IMG_3088.JPG' and '2017/IMG_3088.JPG' are the same file
# mv: '2017/IMG_3098.JPG' and '2017/IMG_3098.JPG' are the same file
# mv: '2017/IMG_3099.JPG' and '2017/IMG_3099.JPG' are the same file
# mv: '2017/IMG_3100.JPG' and '2017/IMG_3100.JPG' are the same file
# mv: '2017/IMG_3167.JPG' and '2017/IMG_3167.JPG' are the same file
# mv: '2017/IMG_3168.JPG' and '2017/IMG_3168.JPG' are the same file
# mv: '2017/IMG_3169.JPG' and '2017/IMG_3169.JPG' are the same file
# mv: '2017/IMG_3170.JPG' and '2017/IMG_3170.JPG' are the same file
# mv: '2017/IMG_3172.JPG' and '2017/IMG_3172.JPG' are the same file
# mv: '2017/IMG_3173.JPG' and '2017/IMG_3173.JPG' are the same file
# mv: '2017/IMG_3174.JPG' and '2017/IMG_3174.JPG' are the same file
# mv: '2017/IMG_3175.JPG' and '2017/IMG_3175.JPG' are the same file
# mv: '2017/IMG_3176.JPG' and '2017/IMG_3176.JPG' are the same file
# mv: '2017/IMG_3177.JPG' and '2017/IMG_3177.JPG' are the same file
# mv: '2017/IMG_3178.JPG' and '2017/IMG_3178.JPG' are the same file
# mv: '2017/IMG_3179.JPG' and '2017/IMG_3179.JPG' are the same file
# mv: '2017/IMG_3181.JPG' and '2017/IMG_3181.JPG' are the same file
# mv: '2017/IMG_3182.JPG' and '2017/IMG_3182.JPG' are the same file
# mv: '2017/IMG_3183.JPG' and '2017/IMG_3183.JPG' are the same file
# mv: '2017/IMG_3184.JPG' and '2017/IMG_3184.JPG' are the same file
# mv: '2017/IMG_3185.JPG' and '2017/IMG_3185.JPG' are the same file
# mv: '2017/IMG_3186.JPG' and '2017/IMG_3186.JPG' are the same file
# mv: '2017/IMG_3187.JPG' and '2017/IMG_3187.JPG' are the same file
# mv: '2017/IMG_3188.JPG' and '2017/IMG_3188.JPG' are the same file
# mv: '2017/IMG_3189.JPG' and '2017/IMG_3189.JPG' are the same file
# mv: '2017/IMG_3190.JPG' and '2017/IMG_3190.JPG' are the same file
# mv: '2017/IMG_3191.JPG' and '2017/IMG_3191.JPG' are the same file
# mv: '2017/IMG_3192.JPG' and '2017/IMG_3192.JPG' are the same file
# mv: '2017/IMG_3193.JPG' and '2017/IMG_3193.JPG' are the same file
# mv: '2017/IMG_3194.JPG' and '2017/IMG_3194.JPG' are the same file
# mv: '2017/IMG_3195.JPG' and '2017/IMG_3195.JPG' are the same file
# mv: '2017/IMG_3196.JPG' and '2017/IMG_3196.JPG' are the same file
# mv: '2017/IMG_3197.JPG' and '2017/IMG_3197.JPG' are the same file
# mv: '2017/IMG_3198.JPG' and '2017/IMG_3198.JPG' are the same file
# mv: '2017/IMG_3199.JPG' and '2017/IMG_3199.JPG' are the same file
# mv: '2017/IMG_3201.JPG' and '2017/IMG_3201.JPG' are the same file
# mv: '2017/IMG_3202.JPG' and '2017/IMG_3202.JPG' are the same file
# mv: '2017/IMG_3203.JPG' and '2017/IMG_3203.JPG' are the same file
# mv: '2017/IMG_3206.JPG' and '2017/IMG_3206.JPG' are the same file
# mv: '2017/IMG_3209.JPG' and '2017/IMG_3209.JPG' are the same file
# mv: '2017/IMG_3210.JPG' and '2017/IMG_3210.JPG' are the same file
# mv: '2017/IMG_3214.JPG' and '2017/IMG_3214.JPG' are the same file
# mv: '2017/IMG_3215.JPG' and '2017/IMG_3215.JPG' are the same file
# mv: '2017/IMG_3218.JPG' and '2017/IMG_3218.JPG' are the same file
# mv: '2017/IMG_3222.JPG' and '2017/IMG_3222.JPG' are the same file
# mv: '2017/IMG_3223.JPG' and '2017/IMG_3223.JPG' are the same file
# mv: '2017/IMG_3224.JPG' and '2017/IMG_3224.JPG' are the same file
# mv: '2017/IMG_3225.JPG' and '2017/IMG_3225.JPG' are the same file
# mv: '2017/IMG_3226.JPG' and '2017/IMG_3226.JPG' are the same file
# mv: '2017/IMG_3227.JPG' and '2017/IMG_3227.JPG' are the same file
# mv: '2017/IMG_3230.JPG' and '2017/IMG_3230.JPG' are the same file
# mv: '2017/IMG_3232.JPG' and '2017/IMG_3232.JPG' are the same file
# mv: '2017/IMG_3236.JPG' and '2017/IMG_3236.JPG' are the same file
# mv: '2017/IMG_3238.JPG' and '2017/IMG_3238.JPG' are the same file
# mv: '2017/IMG_3246.JPG' and '2017/IMG_3246.JPG' are the same file
# mv: '2017/IMG_3247.JPG' and '2017/IMG_3247.JPG' are the same file
# mv: '2017/IMG_3248.JPG' and '2017/IMG_3248.JPG' are the same file
# mv: '2017/IMG_3250.JPG' and '2017/IMG_3250.JPG' are the same file
# mv: '2017/IMG_3251.JPG' and '2017/IMG_3251.JPG' are the same file
# mv: '2017/IMG_3252.JPG' and '2017/IMG_3252.JPG' are the same file
# mv: '2017/IMG_3254.JPG' and '2017/IMG_3254.JPG' are the same file
# mv: '2017/IMG_3268.JPG' and '2017/IMG_3268.JPG' are the same file
# mv: '2017/IMG_3269.JPG' and '2017/IMG_3269.JPG' are the same file
# mv: '2017/IMG_3270.JPG' and '2017/IMG_3270.JPG' are the same file
# mv: '2017/IMG_3271.JPG' and '2017/IMG_3271.JPG' are the same file
# mv: '2017/IMG_3272.JPG' and '2017/IMG_3272.JPG' are the same file
# mv: '2017/IMG_3273.JPG' and '2017/IMG_3273.JPG' are the same file
# mv: '2017/IMG_3274.JPG' and '2017/IMG_3274.JPG' are the same file
# mv: '2017/IMG_3275.JPG' and '2017/IMG_3275.JPG' are the same file
# mv: '2017/IMG_3276.JPG' and '2017/IMG_3276.JPG' are the same file
# mv: '2017/IMG_3277.JPG' and '2017/IMG_3277.JPG' are the same file
# mv: '2017/IMG_3278.JPG' and '2017/IMG_3278.JPG' are the same file
# mv: '2017/IMG_3279.JPG' and '2017/IMG_3279.JPG' are the same file
# mv: '2017/IMG_3280.JPG' and '2017/IMG_3280.JPG' are the same file
# mv: '2017/IMG_3281.JPG' and '2017/IMG_3281.JPG' are the same file
# mv: '2017/IMG_3282.JPG' and '2017/IMG_3282.JPG' are the same file
# mv: '2017/IMG_3285.JPG' and '2017/IMG_3285.JPG' are the same file
# mv: '2017/IMG_3287.JPG' and '2017/IMG_3287.JPG' are the same file
# mv: '2017/IMG_3288.JPG' and '2017/IMG_3288.JPG' are the same file
# mv: '2017/IMG_3294.JPG' and '2017/IMG_3294.JPG' are the same file
# mv: '2017/IMG_3297.JPG' and '2017/IMG_3297.JPG' are the same file
# mv: '2017/IMG_3298.JPG' and '2017/IMG_3298.JPG' are the same file
# mv: '2017/IMG_3299.JPG' and '2017/IMG_3299.JPG' are the same file
# mv: '2017/IMG_3302.JPG' and '2017/IMG_3302.JPG' are the same file
# mv: '2017/IMG_3303.JPG' and '2017/IMG_3303.JPG' are the same file
# mv: '2017/IMG_3304.JPG' and '2017/IMG_3304.JPG' are the same file
# mv: '2017/IMG_3307.JPG' and '2017/IMG_3307.JPG' are the same file
# mv: '2017/IMG_3308.JPG' and '2017/IMG_3308.JPG' are the same file
# mv: '2017/IMG_3309.JPG' and '2017/IMG_3309.JPG' are the same file
# mv: '2017/IMG_3310.JPG' and '2017/IMG_3310.JPG' are the same file
# mv: '2017/IMG_3311.JPG' and '2017/IMG_3311.JPG' are the same file
# mv: '2017/IMG_3312.JPG' and '2017/IMG_3312.JPG' are the same file
# mv: '2017/IMG_3313.JPG' and '2017/IMG_3313.JPG' are the same file
# mv: '2017/IMG_3349.JPG' and '2017/IMG_3349.JPG' are the same file
# mv: '2017/IMG_3350.JPG' and '2017/IMG_3350.JPG' are the same file
# mv: '2017/IMG_3351.JPG' and '2017/IMG_3351.JPG' are the same file
# mv: '2017/IMG_3352.JPG' and '2017/IMG_3352.JPG' are the same file
# mv: '2017/IMG_3356.JPG' and '2017/IMG_3356.JPG' are the same file
# mv: '2017/IMG_3357.JPG' and '2017/IMG_3357.JPG' are the same file
# mv: '2017/IMG_3358.JPG' and '2017/IMG_3358.JPG' are the same file
# mv: '2017/IMG_3359.JPG' and '2017/IMG_3359.JPG' are the same file
# mv: '2017/IMG_3360.JPG' and '2017/IMG_3360.JPG' are the same file
# mv: '2017/IMG_3362.JPG' and '2017/IMG_3362.JPG' are the same file
# mv: '2017/IMG_3363.JPG' and '2017/IMG_3363.JPG' are the same file
# mv: '2017/IMG_3364.JPG' and '2017/IMG_3364.JPG' are the same file
# mv: '2017/IMG_3365.JPG' and '2017/IMG_3365.JPG' are the same file
# mv: '2017/IMG_3366.JPG' and '2017/IMG_3366.JPG' are the same file
# mv: '2017/IMG_3367.JPG' and '2017/IMG_3367.JPG' are the same file
# mv: '2017/IMG_3368.JPG' and '2017/IMG_3368.JPG' are the same file
# mv: '2017/IMG_3369.JPG' and '2017/IMG_3369.JPG' are the same file
# mv: '2017/IMG_3370.JPG' and '2017/IMG_3370.JPG' are the same file
# mv: '2017/IMG_3371.JPG' and '2017/IMG_3371.JPG' are the same file
# mv: '2017/IMG_3372.JPG' and '2017/IMG_3372.JPG' are the same file
# mv: '2017/IMG_3373.JPG' and '2017/IMG_3373.JPG' are the same file
# mv: '2017/IMG_3374.JPG' and '2017/IMG_3374.JPG' are the same file
# mv: '2017/IMG_3375.JPG' and '2017/IMG_3375.JPG' are the same file
# mv: '2017/IMG_3376.JPG' and '2017/IMG_3376.JPG' are the same file
# mv: '2017/IMG_3380.JPG' and '2017/IMG_3380.JPG' are the same file
# mv: '2017/IMG_3381.JPG' and '2017/IMG_3381.JPG' are the same file
# mv: '2017/IMG_3387.JPG' and '2017/IMG_3387.JPG' are the same file
# mv: '2017/IMG_3388.JPG' and '2017/IMG_3388.JPG' are the same file
# mv: '2017/IMG_3392.JPG' and '2017/IMG_3392.JPG' are the same file
# mv: '2017/IMG_3393.JPG' and '2017/IMG_3393.JPG' are the same file
# mv: '2017/IMG_3394.JPG' and '2017/IMG_3394.JPG' are the same file
# mv: '2017/IMG_3395.JPG' and '2017/IMG_3395.JPG' are the same file
# mv: '2017/IMG_3442.JPG' and '2017/IMG_3442.JPG' are the same file
# mv: '2017/IMG_3446.JPG' and '2017/IMG_3446.JPG' are the same file
# mv: '2017/IMG_3447.JPG' and '2017/IMG_3447.JPG' are the same file
# mv: '2017/IMG_3452.JPG' and '2017/IMG_3452.JPG' are the same file
# mv: '2017/IMG_3464.JPG' and '2017/IMG_3464.JPG' are the same file
# mv: '2017/IMG_3465.JPG' and '2017/IMG_3465.JPG' are the same file
# mv: '2017/IMG_3477.JPG' and '2017/IMG_3477.JPG' are the same file
# mv: '2017/IMG_3481.JPG' and '2017/IMG_3481.JPG' are the same file
# mv: '2017/IMG_3490.JPG' and '2017/IMG_3490.JPG' are the same file
# mv: '2017/IMG_3491.JPG' and '2017/IMG_3491.JPG' are the same file
# mv: '2017/IMG_3494.JPG' and '2017/IMG_3494.JPG' are the same file
# mv: '2017/IMG_3498.JPG' and '2017/IMG_3498.JPG' are the same file
# mv: '2017/IMG_3499.JPG' and '2017/IMG_3499.JPG' are the same file
# mv: '2017/IMG_3500.JPG' and '2017/IMG_3500.JPG' are the same file
# mv: '2017/IMG_3501.JPG' and '2017/IMG_3501.JPG' are the same file
# mv: '2017/IMG_3506.JPG' and '2017/IMG_3506.JPG' are the same file
# mv: '2017/IMG_5709.JPG' and '2017/IMG_5709.JPG' are the same file
# mv: '2017/IMG_5729.JPG' and '2017/IMG_5729.JPG' are the same file
# mv: '2017/IMG_9746.JPG' and '2017/IMG_9746.JPG' are the same file
# mv: '2017/IMG_9747.JPG' and '2017/IMG_9747.JPG' are the same file
# mv: '2017/IMG_9748.JPG' and '2017/IMG_9748.JPG' are the same file
# mv: cannot move '2017/Videos' to a subdirectory of itself, '2017/Videos/Videos'
# mv: '2017/ba21486c-2b31-4be9-b16d-3c63cb2b7d87.jpg' and '2017/ba21486c-2b31-4be9-b16d-3c63cb2b7d87.jpg' are the same file
# mv: '2017/bb89da1b-727f-44f4-97df-1ad858c56e89.jpg' and '2017/bb89da1b-727f-44f4-97df-1ad858c56e89.jpg' are the same file
# mv: '2017/c4b5273d-1569-4b3a-b293-48b358571ced.jpg' and '2017/c4b5273d-1569-4b3a-b293-48b358571ced.jpg' are the same file
# mv: '2017/c6d8378f-a659-4159-9f64-d915da2fdb6a.jpg' and '2017/c6d8378f-a659-4159-9f64-d915da2fdb6a.jpg' are the same file
# mv: '2017/d12fe053-62f2-4579-8b8f-e4add42279c3.jpg' and '2017/d12fe053-62f2-4579-8b8f-e4add42279c3.jpg' are the same file
# mv: '2017/e0e2251d-dee7-410c-85cd-39bd96a18ae2.jpg' and '2017/e0e2251d-dee7-410c-85cd-39bd96a18ae2.jpg' are the same file
# mv: '2017/e680b199-ca37-4e7d-87bb-e97d524098a5.jpg' and '2017/e680b199-ca37-4e7d-87bb-e97d524098a5.jpg' are the same file
# mv: '2017/f6faafad-aaec-4ef4-be73-c8da8f3e7f4f.jpg' and '2017/f6faafad-aaec-4ef4-be73-c8da8f3e7f4f.jpg' are the same file
# mv: '2017/fb626a01-66a3-434c-865c-27719b990a12.jpg' and '2017/fb626a01-66a3-434c-865c-27719b990a12.jpg' are the same file
# mv: '2018/00c35356-5e7c-48fe-8db6-85ce4c9943a8.jpg' and '2018/00c35356-5e7c-48fe-8db6-85ce4c9943a8.jpg' are the same file
# mv: '2018/01c18c55-67e4-4a38-afdc-3b13389ab27c.jpg' and '2018/01c18c55-67e4-4a38-afdc-3b13389ab27c.jpg' are the same file
# mv: '2018/023aef3f-c748-46b3-8561-707f6c904582.jpg' and '2018/023aef3f-c748-46b3-8561-707f6c904582.jpg' are the same file
# mv: '2018/0336728d-995e-4cf3-b49c-65ae0e08ec30.jpg' and '2018/0336728d-995e-4cf3-b49c-65ae0e08ec30.jpg' are the same file
# mv: '2018/03f1ea8c-d518-4114-94ef-edcf43191410.jpg' and '2018/03f1ea8c-d518-4114-94ef-edcf43191410.jpg' are the same file
# mv: '2018/05aee430-0599-4991-acd5-278663ea5986.jpg' and '2018/05aee430-0599-4991-acd5-278663ea5986.jpg' are the same file
# mv: '2018/07442e39-2d5d-44e5-aa59-4a8755af5275.jpg' and '2018/07442e39-2d5d-44e5-aa59-4a8755af5275.jpg' are the same file
# mv: '2018/0747b86d-9d71-44d7-87cb-0f6a7cec8198.jpg' and '2018/0747b86d-9d71-44d7-87cb-0f6a7cec8198.jpg' are the same file
# mv: '2018/07a1d39f-7024-4987-86f0-6313d2a97fa7.jpg' and '2018/07a1d39f-7024-4987-86f0-6313d2a97fa7.jpg' are the same file
# mv: '2018/07bbf8ec-5b32-4862-91ad-c51beb9d9321.jpg' and '2018/07bbf8ec-5b32-4862-91ad-c51beb9d9321.jpg' are the same file
# mv: '2018/08b8470e-1a92-4160-a748-4a0b21e1f79c.jpg' and '2018/08b8470e-1a92-4160-a748-4a0b21e1f79c.jpg' are the same file
# mv: '2018/0a243b3b-6425-49db-9cba-f5fffe42c3d2.jpg' and '2018/0a243b3b-6425-49db-9cba-f5fffe42c3d2.jpg' are the same file
# mv: '2018/0a3e5546-5d0f-4856-8998-603baa7fa636.jpg' and '2018/0a3e5546-5d0f-4856-8998-603baa7fa636.jpg' are the same file
# mv: '2018/0c354bd0-b596-47b4-aaf2-2a8f933fb8f9.jpg' and '2018/0c354bd0-b596-47b4-aaf2-2a8f933fb8f9.jpg' are the same file
# mv: '2018/0c5a91b6-85ec-46f8-b007-a3383bc78c5b.jpg' and '2018/0c5a91b6-85ec-46f8-b007-a3383bc78c5b.jpg' are the same file
# mv: '2018/0cc2e183-488d-4d83-9c87-692269cd8fb5.jpg' and '2018/0cc2e183-488d-4d83-9c87-692269cd8fb5.jpg' are the same file
# mv: '2018/0f115b21-a4be-4739-8623-94152313e35d.jpg' and '2018/0f115b21-a4be-4739-8623-94152313e35d.jpg' are the same file
# mv: '2018/103cad1d-384f-42f4-8026-5cc7048d4ee8.jpg' and '2018/103cad1d-384f-42f4-8026-5cc7048d4ee8.jpg' are the same file
# mv: '2018/1141487b-eb06-408c-9f67-1be0e3278d06.jpg' and '2018/1141487b-eb06-408c-9f67-1be0e3278d06.jpg' are the same file
# mv: '2018/11f174c5-f1d7-4616-a839-cd839e6abc45.jpg' and '2018/11f174c5-f1d7-4616-a839-cd839e6abc45.jpg' are the same file
# mv: '2018/142ec9b4-c218-4d62-bd06-ff6934865eae.jpg' and '2018/142ec9b4-c218-4d62-bd06-ff6934865eae.jpg' are the same file
# mv: '2018/16adddbc-302b-4e06-92a0-33ac87016a5e.jpg' and '2018/16adddbc-302b-4e06-92a0-33ac87016a5e.jpg' are the same file
# mv: '2018/17417617-70d7-4be2-bdf0-e8302ce4ff73.jpg' and '2018/17417617-70d7-4be2-bdf0-e8302ce4ff73.jpg' are the same file
# mv: '2018/17aaa5eb-ed23-4c39-a16d-b2363478f2a2.jpg' and '2018/17aaa5eb-ed23-4c39-a16d-b2363478f2a2.jpg' are the same file
# mv: '2018/17bf7ed3-b166-406d-ae93-6c09627c3876.jpg' and '2018/17bf7ed3-b166-406d-ae93-6c09627c3876.jpg' are the same file
# mv: '2018/18b7cfe7-5627-41e6-8339-dd1e965a544b.jpg' and '2018/18b7cfe7-5627-41e6-8339-dd1e965a544b.jpg' are the same file
# mv: '2018/18df342b-2574-4d95-977d-495b7716a003.jpg' and '2018/18df342b-2574-4d95-977d-495b7716a003.jpg' are the same file
# mv: '2018/191dffa3-5f2f-41d0-9e44-2208a9fc2797.jpg' and '2018/191dffa3-5f2f-41d0-9e44-2208a9fc2797.jpg' are the same file
# mv: '2018/19488e5d-07da-45ce-8244-00dab00c4e28.jpg' and '2018/19488e5d-07da-45ce-8244-00dab00c4e28.jpg' are the same file
# mv: '2018/1a1af1f2-c66a-40f3-b3e3-90b17b4d42e5.jpg' and '2018/1a1af1f2-c66a-40f3-b3e3-90b17b4d42e5.jpg' are the same file
# mv: '2018/1af42641-0ac3-48ab-b246-7cc97a549245.jpg' and '2018/1af42641-0ac3-48ab-b246-7cc97a549245.jpg' are the same file
# mv: '2018/1b2878f4-d6ce-47cb-9cbf-89ca33586240.jpg' and '2018/1b2878f4-d6ce-47cb-9cbf-89ca33586240.jpg' are the same file
# mv: '2018/1b97449c-659a-44b6-a21f-cfe685e27e27.jpg' and '2018/1b97449c-659a-44b6-a21f-cfe685e27e27.jpg' are the same file
# mv: '2018/1cf35b84-7f16-4151-813c-87fcee194ab5.jpg' and '2018/1cf35b84-7f16-4151-813c-87fcee194ab5.jpg' are the same file
# mv: '2018/1dcfa8b8-e172-40e3-8dc3-0f2b9d25eec0.jpg' and '2018/1dcfa8b8-e172-40e3-8dc3-0f2b9d25eec0.jpg' are the same file
# mv: '2018/1e3b71bf-db8e-471a-9bcf-06e36e9e6b6e.jpg' and '2018/1e3b71bf-db8e-471a-9bcf-06e36e9e6b6e.jpg' are the same file
# mv: '2018/1e92a7da-2f31-4db7-8a38-3d15dc8ea2eb.jpg' and '2018/1e92a7da-2f31-4db7-8a38-3d15dc8ea2eb.jpg' are the same file
# mv: '2018/1ea22d33-f5a4-48b4-859a-f01dc618aba6.jpg' and '2018/1ea22d33-f5a4-48b4-859a-f01dc618aba6.jpg' are the same file
# mv: '2018/1f5ba3de-495b-413a-af38-62fc3b71e511.jpg' and '2018/1f5ba3de-495b-413a-af38-62fc3b71e511.jpg' are the same file
# mv: '2018/2016.txt' and '2018/2016.txt' are the same file
# mv: '2018/2017.txt' and '2018/2017.txt' are the same file
# mv: '2018/2019.txt' and '2018/2019.txt' are the same file
# mv: '2018/21ECC516-F9BF-48F2-B880-13D2A6B4EB44.jpg' and '2018/21ECC516-F9BF-48F2-B880-13D2A6B4EB44.jpg' are the same file
# mv: '2018/21b38777-bb2a-4348-8a71-75748075cf07.jpg' and '2018/21b38777-bb2a-4348-8a71-75748075cf07.jpg' are the same file
# mv: '2018/2357b138-2282-4164-8710-7b2fa65c2bb8.jpg' and '2018/2357b138-2282-4164-8710-7b2fa65c2bb8.jpg' are the same file
# mv: '2018/2500f0fe-d0c1-4390-a8b2-36e3ff1902ce.jpg' and '2018/2500f0fe-d0c1-4390-a8b2-36e3ff1902ce.jpg' are the same file
# mv: '2018/2542e8d4-6926-4665-bc81-915904296dc4.jpg' and '2018/2542e8d4-6926-4665-bc81-915904296dc4.jpg' are the same file
# mv: '2018/25c80dda-d71f-4efa-9bfd-be54b0d764e9.jpg' and '2018/25c80dda-d71f-4efa-9bfd-be54b0d764e9.jpg' are the same file
# mv: '2018/26407724-5748-414A-B6B5-8D9D67EC4464.jpg' and '2018/26407724-5748-414A-B6B5-8D9D67EC4464.jpg' are the same file
# mv: '2018/2b16a1dd-0055-483b-9ae7-b771e9c3c201.jpg' and '2018/2b16a1dd-0055-483b-9ae7-b771e9c3c201.jpg' are the same file
# mv: '2018/2c1c65eb-7471-47c1-9559-3abdfccb8661.jpg' and '2018/2c1c65eb-7471-47c1-9559-3abdfccb8661.jpg' are the same file
# mv: '2018/2c919e21-4fcf-4085-9d61-21312865108d.jpg' and '2018/2c919e21-4fcf-4085-9d61-21312865108d.jpg' are the same file
# mv: '2018/2ddd9844-3fd3-499b-97ab-2fd923b473cc.jpg' and '2018/2ddd9844-3fd3-499b-97ab-2fd923b473cc.jpg' are the same file
# mv: '2018/2f4eadd7-bb56-475d-bf14-233cffac62d9.jpg' and '2018/2f4eadd7-bb56-475d-bf14-233cffac62d9.jpg' are the same file
# mv: '2018/3035ca93-50fc-4894-8bf7-d7eb5b021fcb.jpg' and '2018/3035ca93-50fc-4894-8bf7-d7eb5b021fcb.jpg' are the same file
# mv: '2018/313a8f53-e36b-47a5-a4a3-d1392cbb270d.jpg' and '2018/313a8f53-e36b-47a5-a4a3-d1392cbb270d.jpg' are the same file
# mv: '2018/31da8214-a5d1-427f-9d88-a6071e0642ca.jpg' and '2018/31da8214-a5d1-427f-9d88-a6071e0642ca.jpg' are the same file
# mv: '2018/32f1228f-e727-4743-bdcd-6a8bf8532fe1.jpg' and '2018/32f1228f-e727-4743-bdcd-6a8bf8532fe1.jpg' are the same file
# mv: '2018/337f7ef9-743d-42e6-bb7e-31487e674294.jpg' and '2018/337f7ef9-743d-42e6-bb7e-31487e674294.jpg' are the same file
# mv: '2018/33ed9bf2-a74c-4f28-8a77-55a3fac94f13.jpg' and '2018/33ed9bf2-a74c-4f28-8a77-55a3fac94f13.jpg' are the same file
# mv: '2018/34aad00c-2d50-4cbe-acbf-72a8c8d2fc04.jpg' and '2018/34aad00c-2d50-4cbe-acbf-72a8c8d2fc04.jpg' are the same file
# mv: '2018/34e0812a-ad19-49fb-b064-38a9cf441fd6.jpg' and '2018/34e0812a-ad19-49fb-b064-38a9cf441fd6.jpg' are the same file
# mv: '2018/36bdbe68-1810-49ed-aa3e-7b43ca880f02.jpg' and '2018/36bdbe68-1810-49ed-aa3e-7b43ca880f02.jpg' are the same file
# mv: '2018/3747da37-eb71-40d5-aed0-5a9125fa3432.jpg' and '2018/3747da37-eb71-40d5-aed0-5a9125fa3432.jpg' are the same file
# mv: '2018/38fe6ca3-26b7-4592-b5ff-6eedf07c6146.jpg' and '2018/38fe6ca3-26b7-4592-b5ff-6eedf07c6146.jpg' are the same file
# mv: '2018/39aacf6c-2621-48c7-94ee-984b8a85189b.jpg' and '2018/39aacf6c-2621-48c7-94ee-984b8a85189b.jpg' are the same file
# mv: '2018/3A2B38FE-6F7A-4C40-8483-0F906C2EAF7E.jpg' and '2018/3A2B38FE-6F7A-4C40-8483-0F906C2EAF7E.jpg' are the same file
# mv: '2018/3CA27F83-FF2B-4105-8B32-18AFDE8B7571.jpg' and '2018/3CA27F83-FF2B-4105-8B32-18AFDE8B7571.jpg' are the same file
# mv: '2018/3a527673-57be-4d19-b77c-a7000c035b07.jpg' and '2018/3a527673-57be-4d19-b77c-a7000c035b07.jpg' are the same file
# mv: '2018/3afa84b7-0cc9-41c3-9750-16d89d14744f.jpg' and '2018/3afa84b7-0cc9-41c3-9750-16d89d14744f.jpg' are the same file
# mv: '2018/3b048a4c-da4a-44ea-8906-8b7b05030416.jpg' and '2018/3b048a4c-da4a-44ea-8906-8b7b05030416.jpg' are the same file
# mv: '2018/3b52bf50-2716-4b1f-b10b-2fea8536ec7b.jpg' and '2018/3b52bf50-2716-4b1f-b10b-2fea8536ec7b.jpg' are the same file
# mv: '2018/3b997fe6-36aa-4e18-a4c6-826c4cca0d28.jpg' and '2018/3b997fe6-36aa-4e18-a4c6-826c4cca0d28.jpg' are the same file
# mv: '2018/3bac58b8-95e9-4af8-8311-a8e9b85c7b9c.jpg' and '2018/3bac58b8-95e9-4af8-8311-a8e9b85c7b9c.jpg' are the same file
# mv: '2018/3d870104-b165-4e3c-9564-4d2409132677.jpg' and '2018/3d870104-b165-4e3c-9564-4d2409132677.jpg' are the same file
# mv: '2018/3dd40306-801a-4410-890d-01635074c37a.jpg' and '2018/3dd40306-801a-4410-890d-01635074c37a.jpg' are the same file
# mv: '2018/3e86fce1-318e-4d75-aacb-2d1042240455.jpg' and '2018/3e86fce1-318e-4d75-aacb-2d1042240455.jpg' are the same file
# mv: '2018/3ebf6fb5-6c25-451b-bb13-205dd7f1633b.jpg' and '2018/3ebf6fb5-6c25-451b-bb13-205dd7f1633b.jpg' are the same file
# mv: '2018/3f8d4887-50ae-4e6d-978f-7bbf55c64c2a.jpg' and '2018/3f8d4887-50ae-4e6d-978f-7bbf55c64c2a.jpg' are the same file
# mv: '2018/401d2e3c-84e8-4798-9637-edc15d234e49.jpg' and '2018/401d2e3c-84e8-4798-9637-edc15d234e49.jpg' are the same file
# mv: '2018/418965c4-035e-409c-a1fb-d264b51c704f.jpg' and '2018/418965c4-035e-409c-a1fb-d264b51c704f.jpg' are the same file
# mv: '2018/41c833eb-46ec-471d-9f1d-3bd6fdececbb.jpg' and '2018/41c833eb-46ec-471d-9f1d-3bd6fdececbb.jpg' are the same file
# mv: '2018/41d6b57d-27f3-442d-914e-d79e46539907.jpg' and '2018/41d6b57d-27f3-442d-914e-d79e46539907.jpg' are the same file
# mv: '2018/4324811c-35fb-45a5-8919-5db4258558e7.jpg' and '2018/4324811c-35fb-45a5-8919-5db4258558e7.jpg' are the same file
# mv: '2018/43479907-7f92-422b-85f5-c3048ffefcb2.jpg' and '2018/43479907-7f92-422b-85f5-c3048ffefcb2.jpg' are the same file
# mv: '2018/438d8ac4-f554-433e-a13c-32610ccc0bfb.jpg' and '2018/438d8ac4-f554-433e-a13c-32610ccc0bfb.jpg' are the same file
# mv: '2018/445a3cef-b356-4bf0-9c61-f4cf5b004386.jpg' and '2018/445a3cef-b356-4bf0-9c61-f4cf5b004386.jpg' are the same file
# mv: '2018/46b019d6-f055-458e-961c-4f87272539db.jpg' and '2018/46b019d6-f055-458e-961c-4f87272539db.jpg' are the same file
# mv: '2018/46eb6ccf-4d77-40ed-9bcc-17a20f084997.jpg' and '2018/46eb6ccf-4d77-40ed-9bcc-17a20f084997.jpg' are the same file
# mv: '2018/470d7ac8-8341-4ac8-bfd3-c9e258d532dd.jpg' and '2018/470d7ac8-8341-4ac8-bfd3-c9e258d532dd.jpg' are the same file
# mv: '2018/47188dfd-ca92-4974-a20c-8ba8b2c37caa.jpg' and '2018/47188dfd-ca92-4974-a20c-8ba8b2c37caa.jpg' are the same file
# mv: '2018/47abd0ca-6cff-439a-8554-0edc58f4d522.jpg' and '2018/47abd0ca-6cff-439a-8554-0edc58f4d522.jpg' are the same file
# mv: '2018/49814624-63c6-41ed-b5ee-5a8a1f7b9f9b.jpg' and '2018/49814624-63c6-41ed-b5ee-5a8a1f7b9f9b.jpg' are the same file
# mv: '2018/4a3ae9d6-351a-4ed1-81f6-64f4904c3f11.jpg' and '2018/4a3ae9d6-351a-4ed1-81f6-64f4904c3f11.jpg' are the same file
# mv: '2018/4a47d869-0a51-4a6f-bdd9-640aa3088473.jpg' and '2018/4a47d869-0a51-4a6f-bdd9-640aa3088473.jpg' are the same file
# mv: '2018/4c093c3e-1451-41d9-bb1e-34ae7d985447.jpg' and '2018/4c093c3e-1451-41d9-bb1e-34ae7d985447.jpg' are the same file
# mv: '2018/4c62dbfd-7996-4f73-b87d-153c527aa0d1.jpg' and '2018/4c62dbfd-7996-4f73-b87d-153c527aa0d1.jpg' are the same file
# mv: '2018/4e0f2c16-55bf-46ab-9460-6eada8bb712b.jpg' and '2018/4e0f2c16-55bf-46ab-9460-6eada8bb712b.jpg' are the same file
# mv: '2018/4e11b03b-0ec2-45fc-afec-be56874bc09e.jpg' and '2018/4e11b03b-0ec2-45fc-afec-be56874bc09e.jpg' are the same file
# mv: '2018/4f7341da-d849-4fd2-862c-07dedc866096.jpg' and '2018/4f7341da-d849-4fd2-862c-07dedc866096.jpg' are the same file
# mv: '2018/5066f93b-63c4-4668-a9ca-20ba68e3942c.jpg' and '2018/5066f93b-63c4-4668-a9ca-20ba68e3942c.jpg' are the same file
# mv: '2018/50b185a4-3ddb-431c-a728-338864d4bf1a.jpg' and '2018/50b185a4-3ddb-431c-a728-338864d4bf1a.jpg' are the same file
# mv: '2018/514b196d-d542-4619-80e0-b45bb64092dc.jpg' and '2018/514b196d-d542-4619-80e0-b45bb64092dc.jpg' are the same file
# mv: '2018/518c5f3c-2602-48d4-a671-2824efa9b0b9.jpg' and '2018/518c5f3c-2602-48d4-a671-2824efa9b0b9.jpg' are the same file
# mv: '2018/51d73040-5c99-46a7-9718-2be1b0261112.jpg' and '2018/51d73040-5c99-46a7-9718-2be1b0261112.jpg' are the same file
# ...
# mv: '2020/IMG_6490.jpg' and '2020/IMG_6490.jpg' are the same file
# mv: '2020/IMG_6491.jpg' and '2020/IMG_6491.jpg' are the same file
# mv: '2020/IMG_6492.jpg' and '2020/IMG_6492.jpg' are the same file
# mv: '2020/IMG_6493.jpg' and '2020/IMG_6493.jpg' are the same file
# mv: '2020/IMG_6494.jpg' and '2020/IMG_6494.jpg' are the same file
# mv: '2020/IMG_6495.jpg' and '2020/IMG_6495.jpg' are the same file
# mv: '2020/IMG_6496.jpg' and '2020/IMG_6496.jpg' are the same file
# mv: '2020/IMG_6497.jpg' and '2020/IMG_6497.jpg' are the same file
# mv: '2020/IMG_6498.jpg' and '2020/IMG_6498.jpg' are the same file
# mv: '2020/IMG_6499.jpg' and '2020/IMG_6499.jpg' are the same file
# mv: '2020/IMG_6500(Edited).jpg' and '2020/IMG_6500(Edited).jpg' are the same file
# mv: '2020/IMG_6500.jpg' and '2020/IMG_6500.jpg' are the same file
# mv: '2020/IMG_6501(Edited).jpg' and '2020/IMG_6501(Edited).jpg' are the same file
# mv: '2020/IMG_6501.jpg' and '2020/IMG_6501.jpg' are the same file
# mv: '2020/IMG_6502(Edited).jpg' and '2020/IMG_6502(Edited).jpg' are the same file
# mv: '2020/IMG_6502.jpg' and '2020/IMG_6502.jpg' are the same file
# mv: '2020/IMG_6503(Edited).jpg' and '2020/IMG_6503(Edited).jpg' are the same file
# mv: '2020/IMG_6503.jpg' and '2020/IMG_6503.jpg' are the same file
# mv: '2020/IMG_6504(Edited).jpg' and '2020/IMG_6504(Edited).jpg' are the same file
# mv: '2020/IMG_6504.jpg' and '2020/IMG_6504.jpg' are the same file
# mv: '2020/IMG_6505(Edited).jpg' and '2020/IMG_6505(Edited).jpg' are the same file
# mv: '2020/IMG_6505.jpg' and '2020/IMG_6505.jpg' are the same file
# mv: '2020/IMG_6506.jpg' and '2020/IMG_6506.jpg' are the same file
# mv: '2020/IMG_6507.jpg' and '2020/IMG_6507.jpg' are the same file
# mv: '2020/IMG_6508.jpg' and '2020/IMG_6508.jpg' are the same file
# mv: '2020/IMG_6509.jpg' and '2020/IMG_6509.jpg' are the same file
# mv: '2020/IMG_6510.jpg' and '2020/IMG_6510.jpg' are the same file
# mv: '2020/IMG_6511.jpg' and '2020/IMG_6511.jpg' are the same file
# mv: '2020/IMG_6512.jpg' and '2020/IMG_6512.jpg' are the same file
# mv: '2020/IMG_6513.jpg' and '2020/IMG_6513.jpg' are the same file
# mv: '2020/IMG_6514.jpg' and '2020/IMG_6514.jpg' are the same file
# mv: '2020/IMG_6515.jpg' and '2020/IMG_6515.jpg' are the same file
# mv: '2020/IMG_6516.jpg' and '2020/IMG_6516.jpg' are the same file
# mv: '2020/IMG_6517.jpg' and '2020/IMG_6517.jpg' are the same file
# mv: '2020/IMG_6518.jpg' and '2020/IMG_6518.jpg' are the same file
# mv: '2020/IMG_6521.jpg' and '2020/IMG_6521.jpg' are the same file
# mv: '2020/IMG_6522.jpg' and '2020/IMG_6522.jpg' are the same file
# mv: '2020/IMG_6523.jpg' and '2020/IMG_6523.jpg' are the same file
# mv: '2020/IMG_6524(Edited).jpg' and '2020/IMG_6524(Edited).jpg' are the same file
# mv: '2020/IMG_6524.jpg' and '2020/IMG_6524.jpg' are the same file
# mv: '2020/IMG_6525.jpg' and '2020/IMG_6525.jpg' are the same file
# mv: '2020/IMG_6526.jpg' and '2020/IMG_6526.jpg' are the same file
# mv: '2020/IMG_6527.jpg' and '2020/IMG_6527.jpg' are the same file
# mv: '2020/IMG_6528.jpg' and '2020/IMG_6528.jpg' are the same file
# mv: '2020/IMG_6535.jpg' and '2020/IMG_6535.jpg' are the same file
# mv: '2020/IMG_6536.jpg' and '2020/IMG_6536.jpg' are the same file
# mv: '2020/IMG_6538(Edited).jpg' and '2020/IMG_6538(Edited).jpg' are the same file
# mv: '2020/IMG_6538.jpg' and '2020/IMG_6538.jpg' are the same file
# mv: '2020/IMG_6539(Edited).jpg' and '2020/IMG_6539(Edited).jpg' are the same file
# mv: '2020/IMG_6539.jpg' and '2020/IMG_6539.jpg' are the same file
# mv: '2020/IMG_6542(Edited).jpg' and '2020/IMG_6542(Edited).jpg' are the same file
# mv: '2020/IMG_6542.jpg' and '2020/IMG_6542.jpg' are the same file
# mv: '2020/IMG_6543(Edited).jpg' and '2020/IMG_6543(Edited).jpg' are the same file
# mv: '2020/IMG_6543.jpg' and '2020/IMG_6543.jpg' are the same file
# mv: '2020/IMG_6544(Edited).jpg' and '2020/IMG_6544(Edited).jpg' are the same file
# mv: '2020/IMG_6544.jpg' and '2020/IMG_6544.jpg' are the same file
# mv: '2020/IMG_6545.jpg' and '2020/IMG_6545.jpg' are the same file
# mv: '2020/IMG_6547.jpg' and '2020/IMG_6547.jpg' are the same file
# mv: '2020/IMG_6548.jpg' and '2020/IMG_6548.jpg' are the same file
# mv: '2020/IMG_6549.jpg' and '2020/IMG_6549.jpg' are the same file
# mv: '2020/IMG_6550.jpg' and '2020/IMG_6550.jpg' are the same file
# mv: '2020/IMG_6551.jpg' and '2020/IMG_6551.jpg' are the same file
# mv: '2020/IMG_6557(Edited).jpg' and '2020/IMG_6557(Edited).jpg' are the same file
# mv: '2020/IMG_6557.jpg' and '2020/IMG_6557.jpg' are the same file
# mv: '2020/IMG_6558(Edited).jpg' and '2020/IMG_6558(Edited).jpg' are the same file
# mv: '2020/IMG_6558.jpg' and '2020/IMG_6558.jpg' are the same file
# mv: '2020/IMG_6559(Edited).jpg' and '2020/IMG_6559(Edited).jpg' are the same file
# mv: '2020/IMG_6559.jpg' and '2020/IMG_6559.jpg' are the same file
# mv: '2020/IMG_6560(Edited).jpg' and '2020/IMG_6560(Edited).jpg' are the same file
# mv: '2020/IMG_6560.jpg' and '2020/IMG_6560.jpg' are the same file
# mv: '2020/IMG_6561(Edited).jpg' and '2020/IMG_6561(Edited).jpg' are the same file
# mv: '2020/IMG_6561.jpg' and '2020/IMG_6561.jpg' are the same file
# mv: '2020/IMG_6562(Edited).jpg' and '2020/IMG_6562(Edited).jpg' are the same file
# mv: '2020/IMG_6562.jpg' and '2020/IMG_6562.jpg' are the same file
# mv: '2020/IMG_6563(Edited).jpg' and '2020/IMG_6563(Edited).jpg' are the same file
# mv: '2020/IMG_6563.jpg' and '2020/IMG_6563.jpg' are the same file
# mv: '2020/IMG_6564(Edited).jpg' and '2020/IMG_6564(Edited).jpg' are the same file
# mv: '2020/IMG_6564.jpg' and '2020/IMG_6564.jpg' are the same file
# mv: '2020/IMG_6567.jpg' and '2020/IMG_6567.jpg' are the same file
# mv: '2020/IMG_6568.jpg' and '2020/IMG_6568.jpg' are the same file
# mv: '2020/IMG_6569.jpg' and '2020/IMG_6569.jpg' are the same file
# mv: '2020/IMG_6570.jpg' and '2020/IMG_6570.jpg' are the same file
# mv: '2020/IMG_6571.jpg' and '2020/IMG_6571.jpg' are the same file
# mv: '2020/IMG_6572.jpg' and '2020/IMG_6572.jpg' are the same file
# mv: '2020/IMG_6795.jpg' and '2020/IMG_6795.jpg' are the same file
# mv: '2020/IMG_6796.jpg' and '2020/IMG_6796.jpg' are the same file
# mv: '2020/IMG_6797.jpg' and '2020/IMG_6797.jpg' are the same file
# mv: '2020/IMG_6798.jpg' and '2020/IMG_6798.jpg' are the same file
# mv: '2020/IMG_6805.jpg' and '2020/IMG_6805.jpg' are the same file
# mv: '2020/IMG_6806.jpg' and '2020/IMG_6806.jpg' are the same file
# mv: '2020/IMG_6807.jpg' and '2020/IMG_6807.jpg' are the same file
# mv: '2020/IMG_6808.jpg' and '2020/IMG_6808.jpg' are the same file
# mv: '2020/IMG_6810.jpg' and '2020/IMG_6810.jpg' are the same file
# mv: '2020/IMG_6839.jpg' and '2020/IMG_6839.jpg' are the same file
# mv: '2020/IMG_6840.jpg' and '2020/IMG_6840.jpg' are the same file
# mv: '2020/IMG_6841.jpg' and '2020/IMG_6841.jpg' are the same file
# mv: '2020/IMG_6842.jpg' and '2020/IMG_6842.jpg' are the same file
# mv: '2020/IMG_6998.jpg' and '2020/IMG_6998.jpg' are the same file
# mv: '2020/IMG_7028.jpg' and '2020/IMG_7028.jpg' are the same file
# mv: '2020/IMG_7029.jpg' and '2020/IMG_7029.jpg' are the same file
# mv: '2020/IMG_7030.jpg' and '2020/IMG_7030.jpg' are the same file
# mv: '2020/IMG_7031(Edited).jpg' and '2020/IMG_7031(Edited).jpg' are the same file
# mv: '2020/IMG_7031.jpg' and '2020/IMG_7031.jpg' are the same file
# mv: '2020/IMG_7032(Edited).jpg' and '2020/IMG_7032(Edited).jpg' are the same file
# mv: '2020/IMG_7032.jpg' and '2020/IMG_7032.jpg' are the same file
# mv: '2020/IMG_7033(Edited).jpg' and '2020/IMG_7033(Edited).jpg' are the same file
# mv: '2020/IMG_7033.jpg' and '2020/IMG_7033.jpg' are the same file
# mv: '2020/IMG_7103.jpg' and '2020/IMG_7103.jpg' are the same file
# mv: '2020/IMG_7104.jpg' and '2020/IMG_7104.jpg' are the same file
# mv: '2020/IMG_7105.jpg' and '2020/IMG_7105.jpg' are the same file
# mv: '2020/IMG_7106.jpg' and '2020/IMG_7106.jpg' are the same file
# mv: '2020/IMG_7108.JPG' and '2020/IMG_7108.JPG' are the same file
# mv: '2020/IMG_7163.jpg' and '2020/IMG_7163.jpg' are the same file
# mv: '2020/IMG_7221.jpg' and '2020/IMG_7221.jpg' are the same file
# mv: '2020/IMG_7222(Edited).jpg' and '2020/IMG_7222(Edited).jpg' are the same file
# mv: '2020/IMG_7222.jpg' and '2020/IMG_7222.jpg' are the same file
# mv: '2020/IMG_7223.jpg' and '2020/IMG_7223.jpg' are the same file
# mv: '2020/IMG_7326(Edited).jpg' and '2020/IMG_7326(Edited).jpg' are the same file
# mv: '2020/IMG_7326.jpg' and '2020/IMG_7326.jpg' are the same file
# mv: '2020/IMG_7327.jpg' and '2020/IMG_7327.jpg' are the same file
# mv: '2020/IMG_7328.jpg' and '2020/IMG_7328.jpg' are the same file
# mv: '2020/IMG_7329.jpg' and '2020/IMG_7329.jpg' are the same file
# mv: '2020/IMG_7330.jpg' and '2020/IMG_7330.jpg' are the same file
# mv: '2020/IMG_7360.jpg' and '2020/IMG_7360.jpg' are the same file
# mv: '2020/IMG_7361.jpg' and '2020/IMG_7361.jpg' are the same file
# mv: '2020/IMG_7362.jpg' and '2020/IMG_7362.jpg' are the same file
# mv: '2020/IMG_7363(Edited).jpg' and '2020/IMG_7363(Edited).jpg' are the same file
# mv: '2020/IMG_7363.jpg' and '2020/IMG_7363.jpg' are the same file
# mv: '2020/IMG_7364.jpg' and '2020/IMG_7364.jpg' are the same file
# mv: '2020/IMG_7365(Edited).jpg' and '2020/IMG_7365(Edited).jpg' are the same file
# mv: '2020/IMG_7365.jpg' and '2020/IMG_7365.jpg' are the same file
# mv: '2020/IMG_7366(Edited).jpg' and '2020/IMG_7366(Edited).jpg' are the same file
# mv: '2020/IMG_7366.jpg' and '2020/IMG_7366.jpg' are the same file
# mv: '2020/IMG_7367(Edited).jpg' and '2020/IMG_7367(Edited).jpg' are the same file
# mv: '2020/IMG_7367.jpg' and '2020/IMG_7367.jpg' are the same file
# mv: '2020/IMG_7370.jpg' and '2020/IMG_7370.jpg' are the same file
# mv: '2020/IMG_7371.jpg' and '2020/IMG_7371.jpg' are the same file
# mv: '2020/IMG_7372.jpg' and '2020/IMG_7372.jpg' are the same file
# mv: '2020/IMG_7373.jpg' and '2020/IMG_7373.jpg' are the same file
# mv: '2020/IMG_7374.jpg' and '2020/IMG_7374.jpg' are the same file
# mv: '2020/IMG_7394.jpg' and '2020/IMG_7394.jpg' are the same file
# mv: '2020/IMG_7395.jpg' and '2020/IMG_7395.jpg' are the same file
# mv: '2020/IMG_7396.jpg' and '2020/IMG_7396.jpg' are the same file
# mv: '2020/IMG_7397.jpg' and '2020/IMG_7397.jpg' are the same file
# mv: '2020/IMG_7398.jpg' and '2020/IMG_7398.jpg' are the same file
# mv: '2020/IMG_7400.jpg' and '2020/IMG_7400.jpg' are the same file
# mv: '2020/IMG_7420.jpg' and '2020/IMG_7420.jpg' are the same file
# mv: '2020/IMG_7421.jpg' and '2020/IMG_7421.jpg' are the same file
# mv: '2020/IMG_7422.jpg' and '2020/IMG_7422.jpg' are the same file
# mv: '2020/IMG_7423.jpg' and '2020/IMG_7423.jpg' are the same file
# mv: '2020/IMG_7667.jpg' and '2020/IMG_7667.jpg' are the same file
# mv: '2020/IMG_7668.jpg' and '2020/IMG_7668.jpg' are the same file
# mv: '2020/IMG_7669.jpg' and '2020/IMG_7669.jpg' are the same file
# mv: '2020/IMG_7670.jpg' and '2020/IMG_7670.jpg' are the same file
# mv: '2020/IMG_7671.jpg' and '2020/IMG_7671.jpg' are the same file
# mv: cannot move '2020/Videos' to a subdirectory of itself, '2020/Videos/Videos'
# mv: '2020/a69d2911-8c2c-4e38-b2b2-1d22b432b773.jpg' and '2020/a69d2911-8c2c-4e38-b2b2-1d22b432b773.jpg' are the same file
# mv: '2020/a9fa6e98-33e9-46a1-ac67-4b131a1613a8.jpg' and '2020/a9fa6e98-33e9-46a1-ac67-4b131a1613a8.jpg' are the same file
# mv: '2020/aaf67bf3-9871-4c56-a013-6f4d2f9397da.jpg' and '2020/aaf67bf3-9871-4c56-a013-6f4d2f9397da.jpg' are the same file
# mv: '2020/ab60e9b9-db78-419a-9058-d510f0e01932.jpg' and '2020/ab60e9b9-db78-419a-9058-d510f0e01932.jpg' are the same file
# mv: '2020/b57b5185-629c-4291-af1e-1ed6f5b8dbac.jpg' and '2020/b57b5185-629c-4291-af1e-1ed6f5b8dbac.jpg' are the same file
# mv: '2020/b91ff3d3-c410-49b0-8eab-ad4d9257eed1.jpg' and '2020/b91ff3d3-c410-49b0-8eab-ad4d9257eed1.jpg' are the same file
# mv: '2020/bbc450da-2e8e-49b8-a7d6-a58bb69fd81a.jpg' and '2020/bbc450da-2e8e-49b8-a7d6-a58bb69fd81a.jpg' are the same file
# mv: '2020/bc0e6201-0c2e-4544-89ec-6c4bdc67bdcf.jpg' and '2020/bc0e6201-0c2e-4544-89ec-6c4bdc67bdcf.jpg' are the same file
# mv: '2020/c1190a17-e86f-49d3-86a9-8dc7e267d4d9.jpg' and '2020/c1190a17-e86f-49d3-86a9-8dc7e267d4d9.jpg' are the same file
# mv: '2020/c6be30fa-7967-4d18-b870-366199f6ce9e.jpg' and '2020/c6be30fa-7967-4d18-b870-366199f6ce9e.jpg' are the same file
# mv: '2020/c752f137-0aa5-4326-998d-bc5f6160a71f.jpg' and '2020/c752f137-0aa5-4326-998d-bc5f6160a71f.jpg' are the same file
# mv: '2020/c88d6fd9-3c17-4f19-af08-085a9cd77a75.jpg' and '2020/c88d6fd9-3c17-4f19-af08-085a9cd77a75.jpg' are the same file
# mv: '2020/ca16eda9-002e-4897-a86d-79662cbaea90.jpg' and '2020/ca16eda9-002e-4897-a86d-79662cbaea90.jpg' are the same file
# mv: '2020/cdbce87b-b326-45ad-9218-f2bb7a9aa78c.jpg' and '2020/cdbce87b-b326-45ad-9218-f2bb7a9aa78c.jpg' are the same file
# mv: '2020/ce4470cf-fb80-49d2-a0cf-683479bf82e1.jpg' and '2020/ce4470cf-fb80-49d2-a0cf-683479bf82e1.jpg' are the same file
# mv: '2020/cf91b8f2-6666-480d-abcf-d671536469ed.jpg' and '2020/cf91b8f2-6666-480d-abcf-d671536469ed.jpg' are the same file
# mv: '2020/d3c672c5-0f37-452d-ba56-73c7761697e0.jpg' and '2020/d3c672c5-0f37-452d-ba56-73c7761697e0.jpg' are the same file
# mv: '2020/d66dbfbf-0f05-45a1-89ae-d34480d485ea.jpg' and '2020/d66dbfbf-0f05-45a1-89ae-d34480d485ea.jpg' are the same file
# mv: '2020/d66dff10-a65c-45c7-889b-b3c0dcc2f1dd.jpg' and '2020/d66dff10-a65c-45c7-889b-b3c0dcc2f1dd.jpg' are the same file
# mv: '2020/d699c012-f93e-45eb-ab9a-7dcfcdfcd717.jpg' and '2020/d699c012-f93e-45eb-ab9a-7dcfcdfcd717.jpg' are the same file
# mv: '2020/dc4bb7c1-c44f-4563-8410-196aaef11fbc.jpg' and '2020/dc4bb7c1-c44f-4563-8410-196aaef11fbc.jpg' are the same file
# mv: '2020/e5798bee-07bd-4ef6-be22-3f33a0d9a9b5.jpg' and '2020/e5798bee-07bd-4ef6-be22-3f33a0d9a9b5.jpg' are the same file
# mv: '2020/e886c49f-6107-427e-bb0e-befc2c4fbb62.jpg' and '2020/e886c49f-6107-427e-bb0e-befc2c4fbb62.jpg' are the same file
# mv: '2020/e9a845ba-2a2b-49d8-a6f3-39acd45a1cb4.jpg' and '2020/e9a845ba-2a2b-49d8-a6f3-39acd45a1cb4.jpg' are the same file
# mv: '2020/ee8ed3ef-dc4d-410b-882c-88a45bbf8f01.jpg' and '2020/ee8ed3ef-dc4d-410b-882c-88a45bbf8f01.jpg' are the same file
# mv: '2020/f21e008a-6550-4f07-9caf-d06264f77184.jpg' and '2020/f21e008a-6550-4f07-9caf-d06264f77184.jpg' are the same file
# mv: '2020/f9bc3731-39df-4f6b-a063-8f641ec5a2f5.jpg' and '2020/f9bc3731-39df-4f6b-a063-8f641ec5a2f5.jpg' are the same file
# mv: '2020/fc8206b7-4526-4808-bd55-0af91a5dfdc2.jpg' and '2020/fc8206b7-4526-4808-bd55-0af91a5dfdc2.jpg' are the same file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-28-1a90fcbea074> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/\nfor f in 20*/*; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/\nfor f in 20*/*; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/Switzerland
# for f in * ; do mv "$f" `echo $f | tr ' ' '_'`; done
# Out:
# mv: 'IMG_1118.jpg' and 'IMG_1118.jpg' are the same file
# mv: 'IMG_1119.jpg' and 'IMG_1119.jpg' are the same file
# mv: 'IMG_1120(Edited).jpg' and 'IMG_1120(Edited).jpg' are the same file
# mv: 'IMG_1120.jpg' and 'IMG_1120.jpg' are the same file
# mv: 'IMG_1121.jpg' and 'IMG_1121.jpg' are the same file
# mv: 'IMG_1122(1).jpg' and 'IMG_1122(1).jpg' are the same file
# mv: 'IMG_1123(Edited).jpg' and 'IMG_1123(Edited).jpg' are the same file
# mv: 'IMG_1131.jpg' and 'IMG_1131.jpg' are the same file
# mv: 'IMG_1134.jpg' and 'IMG_1134.jpg' are the same file
# mv: 'IMG_1135.jpg' and 'IMG_1135.jpg' are the same file
# mv: 'IMG_1136.jpg' and 'IMG_1136.jpg' are the same file
# mv: 'IMG_1137.jpg' and 'IMG_1137.jpg' are the same file
# mv: 'IMG_1138.jpg' and 'IMG_1138.jpg' are the same file
# mv: 'IMG_1142.jpg' and 'IMG_1142.jpg' are the same file
# mv: 'IMG_1143.jpg' and 'IMG_1143.jpg' are the same file
# mv: 'IMG_1144.jpg' and 'IMG_1144.jpg' are the same file
# mv: 'IMG_1145.jpg' and 'IMG_1145.jpg' are the same file
# mv: 'IMG_1146.jpg' and 'IMG_1146.jpg' are the same file
# mv: 'IMG_1147_HEVC.MOV' and 'IMG_1147_HEVC.MOV' are the same file
# mv: 'IMG_1150.jpg' and 'IMG_1150.jpg' are the same file
# mv: 'IMG_1152.jpg' and 'IMG_1152.jpg' are the same file
# mv: 'IMG_1153.jpg' and 'IMG_1153.jpg' are the same file
# mv: 'IMG_1154_HEVC.MOV' and 'IMG_1154_HEVC.MOV' are the same file
# mv: 'IMG_1155_HEVC.MOV' and 'IMG_1155_HEVC.MOV' are the same file
# mv: 'IMG_1156.jpg' and 'IMG_1156.jpg' are the same file
# mv: 'IMG_1157.jpg' and 'IMG_1157.jpg' are the same file
# mv: 'IMG_1159_HEVC.MOV' and 'IMG_1159_HEVC.MOV' are the same file
# mv: 'IMG_1160.jpg' and 'IMG_1160.jpg' are the same file
# mv: 'IMG_1167.JPG' and 'IMG_1167.JPG' are the same file
# mv: 'IMG_1168.JPG' and 'IMG_1168.JPG' are the same file
# mv: 'IMG_1169.JPG' and 'IMG_1169.JPG' are the same file
# mv: 'IMG_1170.jpg' and 'IMG_1170.jpg' are the same file
# mv: 'IMG_1171.JPG' and 'IMG_1171.JPG' are the same file
# mv: 'IMG_1172.JPG' and 'IMG_1172.JPG' are the same file
# mv: 'IMG_1173.JPG' and 'IMG_1173.JPG' are the same file
# mv: 'IMG_1174.JPG' and 'IMG_1174.JPG' are the same file
# mv: 'IMG_1175.JPG' and 'IMG_1175.JPG' are the same file
# mv: 'IMG_1176.jpg' and 'IMG_1176.jpg' are the same file
# mv: 'IMG_1177.jpg' and 'IMG_1177.jpg' are the same file
# mv: 'IMG_1178.jpg' and 'IMG_1178.jpg' are the same file
# mv: 'IMG_1179.jpg' and 'IMG_1179.jpg' are the same file
# mv: 'IMG_1190.PNG' and 'IMG_1190.PNG' are the same file
# mv: 'IMG_1196.jpg' and 'IMG_1196.jpg' are the same file
# mv: 'IMG_1197.jpg' and 'IMG_1197.jpg' are the same file
# mv: 'IMG_1198.jpg' and 'IMG_1198.jpg' are the same file
# mv: 'IMG_1200.jpg' and 'IMG_1200.jpg' are the same file
# mv: 'IMG_1202.jpg' and 'IMG_1202.jpg' are the same file
# mv: 'IMG_1203.jpg' and 'IMG_1203.jpg' are the same file
# mv: 'IMG_1204.jpg' and 'IMG_1204.jpg' are the same file
# mv: 'IMG_1205.JPG' and 'IMG_1205.JPG' are the same file
# mv: 'IMG_1206.JPG' and 'IMG_1206.JPG' are the same file
# mv: 'IMG_1208.JPG' and 'IMG_1208.JPG' are the same file
# mv: 'IMG_1209.JPG' and 'IMG_1209.JPG' are the same file
# mv: 'IMG_1210.jpg' and 'IMG_1210.jpg' are the same file
# mv: 'IMG_1212.jpg' and 'IMG_1212.jpg' are the same file
# mv: 'IMG_1213.JPG' and 'IMG_1213.JPG' are the same file
# mv: 'IMG_1214(Edited).jpg' and 'IMG_1214(Edited).jpg' are the same file
# mv: 'IMG_1214.JPG' and 'IMG_1214.JPG' are the same file
# mv: 'IMG_1215.JPG' and 'IMG_1215.JPG' are the same file
# mv: 'IMG_1217_HEVC.MOV' and 'IMG_1217_HEVC.MOV' are the same file
# mv: 'IMG_1220(1).jpg' and 'IMG_1220(1).jpg' are the same file
# mv: 'IMG_1222(1).jpg' and 'IMG_1222(1).jpg' are the same file
# mv: 'IMG_1223(1).jpg' and 'IMG_1223(1).jpg' are the same file
# mv: 'IMG_1223(Edited).jpg' and 'IMG_1223(Edited).jpg' are the same file
# mv: 'IMG_1223.jpg' and 'IMG_1223.jpg' are the same file
# mv: 'IMG_1224(Edited).jpg' and 'IMG_1224(Edited).jpg' are the same file
# mv: 'IMG_1224.jpg' and 'IMG_1224.jpg' are the same file
# mv: 'IMG_1225(1).jpg' and 'IMG_1225(1).jpg' are the same file
# mv: 'IMG_1225.jpg' and 'IMG_1225.jpg' are the same file
# mv: 'IMG_1226(1).jpg' and 'IMG_1226(1).jpg' are the same file
# mv: 'IMG_1226(Edited).jpg' and 'IMG_1226(Edited).jpg' are the same file
# mv: 'IMG_1226.jpg' and 'IMG_1226.jpg' are the same file
# mv: 'IMG_1227.jpg' and 'IMG_1227.jpg' are the same file
# mv: 'IMG_1228(1).jpg' and 'IMG_1228(1).jpg' are the same file
# mv: 'IMG_1228(Edited).jpg' and 'IMG_1228(Edited).jpg' are the same file
# mv: 'IMG_1229(1).jpg' and 'IMG_1229(1).jpg' are the same file
# mv: 'IMG_1230(1).jpg' and 'IMG_1230(1).jpg' are the same file
# mv: 'IMG_1231(1).jpg' and 'IMG_1231(1).jpg' are the same file
# mv: 'IMG_1232(1).jpg' and 'IMG_1232(1).jpg' are the same file
# mv: 'IMG_1233(1).jpg' and 'IMG_1233(1).jpg' are the same file
# mv: 'IMG_1235(1).jpg' and 'IMG_1235(1).jpg' are the same file
# mv: 'IMG_1235.JPG' and 'IMG_1235.JPG' are the same file
# mv: 'IMG_1236(1).jpg' and 'IMG_1236(1).jpg' are the same file
# mv: 'IMG_1236.JPG' and 'IMG_1236.JPG' are the same file
# mv: 'IMG_1237(1).jpg' and 'IMG_1237(1).jpg' are the same file
# mv: 'IMG_1237.JPG' and 'IMG_1237.JPG' are the same file
# mv: 'IMG_1238(1).jpg' and 'IMG_1238(1).jpg' are the same file
# mv: 'IMG_1238.JPG' and 'IMG_1238.JPG' are the same file
# mv: 'IMG_1239(1).jpg' and 'IMG_1239(1).jpg' are the same file
# mv: 'IMG_1239.JPG' and 'IMG_1239.JPG' are the same file
# mv: 'IMG_1240(1).jpg' and 'IMG_1240(1).jpg' are the same file
# mv: 'IMG_1240.JPG' and 'IMG_1240.JPG' are the same file
# mv: 'IMG_1241.jpg' and 'IMG_1241.jpg' are the same file
# mv: 'IMG_1242(Edited).jpg' and 'IMG_1242(Edited).jpg' are the same file
# mv: 'IMG_1242.jpg' and 'IMG_1242.jpg' are the same file
# mv: 'IMG_1243(Edited).jpg' and 'IMG_1243(Edited).jpg' are the same file
# mv: 'IMG_1243.jpg' and 'IMG_1243.jpg' are the same file
# mv: 'IMG_1244(Edited).jpg' and 'IMG_1244(Edited).jpg' are the same file
# mv: 'IMG_1244.jpg' and 'IMG_1244.jpg' are the same file
# mv: 'IMG_1245.jpg' and 'IMG_1245.jpg' are the same file
# mv: 'IMG_1246.jpg' and 'IMG_1246.jpg' are the same file
# mv: 'IMG_1247(Edited).jpg' and 'IMG_1247(Edited).jpg' are the same file
# mv: 'IMG_1247.jpg' and 'IMG_1247.jpg' are the same file
# mv: 'IMG_1248(Edited).jpg' and 'IMG_1248(Edited).jpg' are the same file
# mv: 'IMG_1248.jpg' and 'IMG_1248.jpg' are the same file
# mv: 'IMG_1249(Edited).jpg' and 'IMG_1249(Edited).jpg' are the same file
# mv: 'IMG_1249.jpg' and 'IMG_1249.jpg' are the same file
# mv: 'IMG_1250(Edited).jpg' and 'IMG_1250(Edited).jpg' are the same file
# mv: 'IMG_1250.jpg' and 'IMG_1250.jpg' are the same file
# mv: 'IMG_1251(Edited).jpg' and 'IMG_1251(Edited).jpg' are the same file
# mv: 'IMG_1251.jpg' and 'IMG_1251.jpg' are the same file
# mv: 'IMG_1252.JPG' and 'IMG_1252.JPG' are the same file
# mv: 'IMG_1253.JPG' and 'IMG_1253.JPG' are the same file
# mv: 'IMG_1255.jpg' and 'IMG_1255.jpg' are the same file
# mv: 'IMG_1256(Edited).jpg' and 'IMG_1256(Edited).jpg' are the same file
# mv: 'IMG_1256.jpg' and 'IMG_1256.jpg' are the same file
# mv: 'IMG_1257(1).jpg' and 'IMG_1257(1).jpg' are the same file
# mv: 'IMG_1258.jpg' and 'IMG_1258.jpg' are the same file
# mv: 'IMG_1259.jpg' and 'IMG_1259.jpg' are the same file
# mv: 'IMG_1260.jpg' and 'IMG_1260.jpg' are the same file
# mv: 'IMG_1261.jpg' and 'IMG_1261.jpg' are the same file
# mv: 'IMG_1262.jpg' and 'IMG_1262.jpg' are the same file
# mv: 'IMG_1263(Edited).jpg' and 'IMG_1263(Edited).jpg' are the same file
# mv: 'IMG_1263.jpg' and 'IMG_1263.jpg' are the same file
# mv: 'IMG_1265.jpg' and 'IMG_1265.jpg' are the same file
# mv: 'IMG_1266.jpg' and 'IMG_1266.jpg' are the same file
# mv: 'IMG_1267.jpg' and 'IMG_1267.jpg' are the same file
# mv: 'IMG_1269(Edited).jpg' and 'IMG_1269(Edited).jpg' are the same file
# mv: 'IMG_1271.jpg' and 'IMG_1271.jpg' are the same file
# mv: 'IMG_1272.jpg' and 'IMG_1272.jpg' are the same file
# mv: 'IMG_1273(1).jpg' and 'IMG_1273(1).jpg' are the same file
# mv: 'IMG_1274.jpg' and 'IMG_1274.jpg' are the same file
# mv: 'IMG_1275.jpg' and 'IMG_1275.jpg' are the same file
# mv: 'IMG_1278.jpg' and 'IMG_1278.jpg' are the same file
# mv: 'IMG_1279.jpg' and 'IMG_1279.jpg' are the same file
# mv: 'IMG_1280.jpg' and 'IMG_1280.jpg' are the same file
# mv: 'IMG_1281.jpg' and 'IMG_1281.jpg' are the same file
# mv: 'IMG_1282.jpg' and 'IMG_1282.jpg' are the same file
# mv: 'IMG_1285_HEVC.MOV' and 'IMG_1285_HEVC.MOV' are the same file
# mv: 'IMG_1286_HEVC.MOV' and 'IMG_1286_HEVC.MOV' are the same file
# mv: 'IMG_1287_HEVC.MOV' and 'IMG_1287_HEVC.MOV' are the same file
# mv: 'IMG_1291(Edited).jpg' and 'IMG_1291(Edited).jpg' are the same file
# mv: 'IMG_1292(Edited).jpg' and 'IMG_1292(Edited).jpg' are the same file
# mv: 'IMG_1293.jpg' and 'IMG_1293.jpg' are the same file
# mv: 'IMG_1296.jpg' and 'IMG_1296.jpg' are the same file
# mv: 'IMG_1297.jpg' and 'IMG_1297.jpg' are the same file
# mv: 'IMG_1299.jpg' and 'IMG_1299.jpg' are the same file
# mv: 'IMG_1300.jpg' and 'IMG_1300.jpg' are the same file
# mv: 'IMG_1301.jpg' and 'IMG_1301.jpg' are the same file
# mv: 'IMG_1302.jpg' and 'IMG_1302.jpg' are the same file
# mv: 'IMG_1303.jpg' and 'IMG_1303.jpg' are the same file
# mv: 'IMG_1322(1).JPG' and 'IMG_1322(1).JPG' are the same file
# mv: 'IMG_1323.JPG' and 'IMG_1323.JPG' are the same file
# mv: 'IMG_1324.JPG' and 'IMG_1324.JPG' are the same file
# mv: 'IMG_1325.JPG' and 'IMG_1325.JPG' are the same file
# mv: 'IMG_1326.JPG' and 'IMG_1326.JPG' are the same file
# mv: 'IMG_1327.JPG' and 'IMG_1327.JPG' are the same file
# mv: 'IMG_1330.JPG' and 'IMG_1330.JPG' are the same file
# mv: 'IMG_1331.JPG' and 'IMG_1331.JPG' are the same file
# mv: 'IMG_1333.JPG' and 'IMG_1333.JPG' are the same file
# mv: 'IMG_1336.JPG' and 'IMG_1336.JPG' are the same file
# mv: 'IMG_1337.JPG' and 'IMG_1337.JPG' are the same file
# mv: 'IMG_1338.JPG' and 'IMG_1338.JPG' are the same file
# mv: 'IMG_1339.JPG' and 'IMG_1339.JPG' are the same file
# mv: 'IMG_1343.JPG' and 'IMG_1343.JPG' are the same file
# mv: 'IMG_1344.JPG' and 'IMG_1344.JPG' are the same file
# mv: 'IMG_1345.jpg' and 'IMG_1345.jpg' are the same file
# mv: 'IMG_1347.jpg' and 'IMG_1347.jpg' are the same file
# mv: 'IMG_1351.jpg' and 'IMG_1351.jpg' are the same file
# mv: 'IMG_1352.jpg' and 'IMG_1352.jpg' are the same file
# mv: 'IMG_1353.jpg' and 'IMG_1353.jpg' are the same file
# mv: 'IMG_1354.jpg' and 'IMG_1354.jpg' are the same file
# mv: 'IMG_1355.jpg' and 'IMG_1355.jpg' are the same file
# mv: 'IMG_1356.jpg' and 'IMG_1356.jpg' are the same file
# mv: 'IMG_1357.jpg' and 'IMG_1357.jpg' are the same file
# mv: 'IMG_1359.jpg' and 'IMG_1359.jpg' are the same file
# mv: 'IMG_1360.jpg' and 'IMG_1360.jpg' are the same file
# mv: 'IMG_1361.jpg' and 'IMG_1361.jpg' are the same file
# mv: 'IMG_1369.jpg' and 'IMG_1369.jpg' are the same file
# mv: 'IMG_1370(1).jpg' and 'IMG_1370(1).jpg' are the same file
# mv: 'IMG_1372(1).jpg' and 'IMG_1372(1).jpg' are the same file
# mv: 'IMG_1374.jpg' and 'IMG_1374.jpg' are the same file
# mv: 'IMG_1375.jpg' and 'IMG_1375.jpg' are the same file
# mv: 'IMG_1376(1).jpg' and 'IMG_1376(1).jpg' are the same file
# mv: 'IMG_1377(1).jpg' and 'IMG_1377(1).jpg' are the same file
# mv: 'IMG_1378.jpg' and 'IMG_1378.jpg' are the same file
# mv: 'IMG_1379.jpg' and 'IMG_1379.jpg' are the same file
# mv: 'IMG_1381.jpg' and 'IMG_1381.jpg' are the same file
# mv: 'IMG_1382.jpg' and 'IMG_1382.jpg' are the same file
# mv: 'IMG_1383.jpg' and 'IMG_1383.jpg' are the same file
# mv: 'IMG_1384.jpg' and 'IMG_1384.jpg' are the same file
# mv: 'IMG_1385.jpg' and 'IMG_1385.jpg' are the same file
# mv: 'IMG_1386.jpg' and 'IMG_1386.jpg' are the same file
# mv: 'IMG_1387(1).jpg' and 'IMG_1387(1).jpg' are the same file
# mv: 'IMG_1388.jpg' and 'IMG_1388.jpg' are the same file
# mv: 'IMG_1390_HEVC.MOV' and 'IMG_1390_HEVC.MOV' are the same file
# mv: 'IMG_1391_HEVC.MOV' and 'IMG_1391_HEVC.MOV' are the same file
# mv: 'IMG_1392.jpg' and 'IMG_1392.jpg' are the same file
# mv: 'IMG_1393.jpg' and 'IMG_1393.jpg' are the same file
# mv: 'IMG_1394.jpg' and 'IMG_1394.jpg' are the same file
# mv: 'IMG_1397.jpg' and 'IMG_1397.jpg' are the same file
# mv: 'IMG_1398.jpg' and 'IMG_1398.jpg' are the same file
# mv: 'IMG_1399.jpg' and 'IMG_1399.jpg' are the same file
# mv: 'IMG_1400.jpg' and 'IMG_1400.jpg' are the same file
# mv: 'IMG_1406.jpg' and 'IMG_1406.jpg' are the same file
# mv: 'IMG_1412.jpg' and 'IMG_1412.jpg' are the same file
# mv: 'IMG_1414(1).jpg' and 'IMG_1414(1).jpg' are the same file
# mv: 'IMG_1415_HEVC.MOV' and 'IMG_1415_HEVC.MOV' are the same file
# mv: 'IMG_1416_HEVC.MOV' and 'IMG_1416_HEVC.MOV' are the same file
# mv: 'IMG_1417_HEVC.MOV' and 'IMG_1417_HEVC.MOV' are the same file
# mv: 'IMG_1418_HEVC.MOV' and 'IMG_1418_HEVC.MOV' are the same file
# mv: 'IMG_1419_HEVC.MOV' and 'IMG_1419_HEVC.MOV' are the same file
# mv: 'IMG_1421.jpg' and 'IMG_1421.jpg' are the same file
# mv: 'IMG_1426.JPG' and 'IMG_1426.JPG' are the same file
# mv: 'IMG_1427.JPG' and 'IMG_1427.JPG' are the same file
# mv: 'IMG_1428.JPG' and 'IMG_1428.JPG' are the same file
# mv: 'IMG_1429.JPG' and 'IMG_1429.JPG' are the same file
# mv: 'IMG_1430.JPG' and 'IMG_1430.JPG' are the same file
# mv: 'IMG_1431.JPG' and 'IMG_1431.JPG' are the same file
# mv: 'IMG_1432.JPG' and 'IMG_1432.JPG' are the same file
# mv: 'IMG_1433.JPG' and 'IMG_1433.JPG' are the same file
# mv: 'IMG_1434.JPG' and 'IMG_1434.JPG' are the same file
# mv: 'IMG_1439.jpg' and 'IMG_1439.jpg' are the same file
# mv: 'IMG_1452_HEVC.MOV' and 'IMG_1452_HEVC.MOV' are the same file
# mv: 'IMG_1455.jpg' and 'IMG_1455.jpg' are the same file
# mv: 'IMG_1456.jpg' and 'IMG_1456.jpg' are the same file
# mv: 'IMG_1457.jpg' and 'IMG_1457.jpg' are the same file
# mv: 'IMG_1458.jpg' and 'IMG_1458.jpg' are the same file
# mv: 'IMG_1461.jpg' and 'IMG_1461.jpg' are the same file
# mv: 'IMG_1472.jpg' and 'IMG_1472.jpg' are the same file
# mv: 'IMG_1483.jpg' and 'IMG_1483.jpg' are the same file
# mv: 'IMG_1516_HEVC.MOV' and 'IMG_1516_HEVC.MOV' are the same file
# mv: 'IMG_1558(Edited).jpg' and 'IMG_1558(Edited).jpg' are the same file
# mv: 'IMG_1559_HEVC.MOV' and 'IMG_1559_HEVC.MOV' are the same file
# mv: 'IMG_1563.jpg' and 'IMG_1563.jpg' are the same file
# mv: 'IMG_1564.jpg' and 'IMG_1564.jpg' are the same file
# mv: 'IMG_1565.jpg' and 'IMG_1565.jpg' are the same file
# mv: 'IMG_1566.jpg' and 'IMG_1566.jpg' are the same file
# mv: 'IMG_1567.jpg' and 'IMG_1567.jpg' are the same file
# mv: 'IMG_1568.jpg' and 'IMG_1568.jpg' are the same file
# mv: 'IMG_1569.jpg' and 'IMG_1569.jpg' are the same file
# mv: 'IMG_1570_HEVC.MOV' and 'IMG_1570_HEVC.MOV' are the same file
# mv: 'IMG_1571_HEVC.MOV' and 'IMG_1571_HEVC.MOV' are the same file
# mv: 'IMG_1572_HEVC.MOV' and 'IMG_1572_HEVC.MOV' are the same file
# mv: 'IMG_1573_HEVC.MOV' and 'IMG_1573_HEVC.MOV' are the same file
# mv: 'IMG_1576.jpg' and 'IMG_1576.jpg' are the same file
# mv: 'IMG_1577.jpg' and 'IMG_1577.jpg' are the same file
# mv: 'IMG_1616.jpg' and 'IMG_1616.jpg' are the same file
# mv: 'IMG_1618.jpg' and 'IMG_1618.jpg' are the same file
# mv: 'IMG_1620.jpg' and 'IMG_1620.jpg' are the same file
# mv: 'IMG_1621.jpg' and 'IMG_1621.jpg' are the same file
# mv: 'IMG_1622.jpg' and 'IMG_1622.jpg' are the same file
# mv: 'IMG_1623.jpg' and 'IMG_1623.jpg' are the same file
# mv: 'IMG_1625.jpg' and 'IMG_1625.jpg' are the same file
# mv: 'IMG_1626.jpg' and 'IMG_1626.jpg' are the same file
# mv: 'IMG_1628.jpg' and 'IMG_1628.jpg' are the same file
# mv: 'IMG_1629.jpg' and 'IMG_1629.jpg' are the same file
# mv: 'IMG_1630.jpg' and 'IMG_1630.jpg' are the same file
# mv: 'IMG_1633.jpg' and 'IMG_1633.jpg' are the same file
# mv: 'IMG_1634.jpg' and 'IMG_1634.jpg' are the same file
# mv: 'IMG_1645_HEVC.MOV' and 'IMG_1645_HEVC.MOV' are the same file
# mv: 'IMG_1646_HEVC.MOV' and 'IMG_1646_HEVC.MOV' are the same file
# mv: 'IMG_1647_HEVC.MOV' and 'IMG_1647_HEVC.MOV' are the same file
# mv: 'IMG_1648_HEVC.MOV' and 'IMG_1648_HEVC.MOV' are the same file
# mv: 'IMG_1649_HEVC.MOV' and 'IMG_1649_HEVC.MOV' are the same file
# mv: 'IMG_1651_HEVC.MOV' and 'IMG_1651_HEVC.MOV' are the same file
# mv: 'IMG_1652_HEVC.MOV' and 'IMG_1652_HEVC.MOV' are the same file
# mv: 'IMG_1653.jpg' and 'IMG_1653.jpg' are the same file
# mv: 'IMG_1654.jpg' and 'IMG_1654.jpg' are the same file
# mv: 'IMG_1655.jpg' and 'IMG_1655.jpg' are the same file
# mv: 'IMG_1656.jpg' and 'IMG_1656.jpg' are the same file
# mv: 'IMG_1657.jpg' and 'IMG_1657.jpg' are the same file
# mv: 'IMG_1658.jpg' and 'IMG_1658.jpg' are the same file
# mv: 'IMG_1659.jpg' and 'IMG_1659.jpg' are the same file
# mv: 'IMG_1660.jpg' and 'IMG_1660.jpg' are the same file
# mv: 'IMG_1661.jpg' and 'IMG_1661.jpg' are the same file
# mv: 'IMG_1662.jpg' and 'IMG_1662.jpg' are the same file
# mv: 'IMG_1663.jpg' and 'IMG_1663.jpg' are the same file
# mv: 'IMG_1664.jpg' and 'IMG_1664.jpg' are the same file
# mv: 'IMG_1665.jpg' and 'IMG_1665.jpg' are the same file
# mv: 'IMG_1666.jpg' and 'IMG_1666.jpg' are the same file
# mv: 'IMG_1667.jpg' and 'IMG_1667.jpg' are the same file
# mv: 'IMG_1668.jpg' and 'IMG_1668.jpg' are the same file
# mv: 'IMG_1669.jpg' and 'IMG_1669.jpg' are the same file
# mv: 'IMG_1670.jpg' and 'IMG_1670.jpg' are the same file
# mv: 'IMG_1671.jpg' and 'IMG_1671.jpg' are the same file
# mv: 'IMG_1672.jpg' and 'IMG_1672.jpg' are the same file
# mv: 'IMG_1673.jpg' and 'IMG_1673.jpg' are the same file
# mv: 'IMG_1679.PNG' and 'IMG_1679.PNG' are the same file
# mv: 'IMG_1708.jpg' and 'IMG_1708.jpg' are the same file
# mv: 'IMG_1743.JPG' and 'IMG_1743.JPG' are the same file
# mv: 'IMG_1746.JPG' and 'IMG_1746.JPG' are the same file
# mv: 'IMG_1759.JPG' and 'IMG_1759.JPG' are the same file
# mv: 'IMG_1760.JPG' and 'IMG_1760.JPG' are the same file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-30-d81fcb45a01c> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/Switzerland\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/Switzerland\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/TrumpHotel
# for f in * ; do mv "$f" `echo $f | tr ' ' '_'`; done
# Out:
# mv: '0ddf7a69-6025-4c2e-9f14-f8ab16e02a2b.jpg' and '0ddf7a69-6025-4c2e-9f14-f8ab16e02a2b.jpg' are the same file
# mv: '1257ccb1-ad31-4f41-9cc3-4328ec18789c.jpg' and '1257ccb1-ad31-4f41-9cc3-4328ec18789c.jpg' are the same file
# mv: '24925584-a4ef-4275-9b9a-0d7d8e256eb0.jpg' and '24925584-a4ef-4275-9b9a-0d7d8e256eb0.jpg' are the same file
# mv: '2f598164-aea0-4975-b649-f729fab26df2.jpg' and '2f598164-aea0-4975-b649-f729fab26df2.jpg' are the same file
# mv: '32da33e3-a2a5-4257-976f-c5aa0463bd02.jpg' and '32da33e3-a2a5-4257-976f-c5aa0463bd02.jpg' are the same file
# mv: '40c0a0fd-79dd-4af1-9734-77682ea0a51a.jpg' and '40c0a0fd-79dd-4af1-9734-77682ea0a51a.jpg' are the same file
# mv: '41110978-49d9-49d9-8c13-b3715ac40043.jpg' and '41110978-49d9-49d9-8c13-b3715ac40043.jpg' are the same file
# mv: '4dcc72d0-8aad-4714-b419-0e2527444b22.jpg' and '4dcc72d0-8aad-4714-b419-0e2527444b22.jpg' are the same file
# mv: '75440a73-f4a5-40de-8a00-03c08b8ea3f3.jpg' and '75440a73-f4a5-40de-8a00-03c08b8ea3f3.jpg' are the same file
# mv: '7e867874-12fe-41ee-9777-79aa65c62d10.jpg' and '7e867874-12fe-41ee-9777-79aa65c62d10.jpg' are the same file
# mv: '7f39a6d8-63ab-4cb4-a39b-351959836dfc.jpg' and '7f39a6d8-63ab-4cb4-a39b-351959836dfc.jpg' are the same file
# mv: '7f9529ba-8965-4f66-9ace-1046b35a733c.jpg' and '7f9529ba-8965-4f66-9ace-1046b35a733c.jpg' are the same file
# mv: '82afcfa9-b807-4237-9dda-3fa8912cc550.jpg' and '82afcfa9-b807-4237-9dda-3fa8912cc550.jpg' are the same file
# mv: '896851aa-b997-4b8d-85ff-c23d06379f00.jpg' and '896851aa-b997-4b8d-85ff-c23d06379f00.jpg' are the same file
# mv: '89a177fb-d5da-44d3-8449-f879a1c3894f.jpg' and '89a177fb-d5da-44d3-8449-f879a1c3894f.jpg' are the same file
# mv: 'B309143E-BBAA-4039-B330-E2D21557894E.jpg' and 'B309143E-BBAA-4039-B330-E2D21557894E.jpg' are the same file
# mv: 'IMG_1460.jpg' and 'IMG_1460.jpg' are the same file
# mv: 'IMG_1462.jpg' and 'IMG_1462.jpg' are the same file
# mv: 'IMG_1463.jpg' and 'IMG_1463.jpg' are the same file
# mv: 'IMG_1464.jpg' and 'IMG_1464.jpg' are the same file
# mv: 'IMG_1465.jpg' and 'IMG_1465.jpg' are the same file
# mv: 'IMG_1466.JPG' and 'IMG_1466.JPG' are the same file
# mv: 'IMG_1467.jpg' and 'IMG_1467.jpg' are the same file
# mv: 'IMG_1468.jpg' and 'IMG_1468.jpg' are the same file
# mv: 'IMG_1470.jpg' and 'IMG_1470.jpg' are the same file
# mv: 'IMG_1471.jpg' and 'IMG_1471.jpg' are the same file
# mv: 'IMG_1473.jpg' and 'IMG_1473.jpg' are the same file
# mv: 'IMG_1474.jpg' and 'IMG_1474.jpg' are the same file
# mv: 'IMG_1475.jpg' and 'IMG_1475.jpg' are the same file
# mv: 'IMG_1476.jpg' and 'IMG_1476.jpg' are the same file
# mv: 'IMG_1477.jpg' and 'IMG_1477.jpg' are the same file
# mv: 'IMG_1478.jpg' and 'IMG_1478.jpg' are the same file
# mv: 'IMG_1479.jpg' and 'IMG_1479.jpg' are the same file
# mv: 'IMG_1480.jpg' and 'IMG_1480.jpg' are the same file
# mv: 'IMG_1481.jpg' and 'IMG_1481.jpg' are the same file
# mv: 'IMG_1482.JPG' and 'IMG_1482.JPG' are the same file
# mv: 'IMG_1484.jpg' and 'IMG_1484.jpg' are the same file
# mv: 'IMG_1485.jpg' and 'IMG_1485.jpg' are the same file
# mv: 'IMG_1486.jpg' and 'IMG_1486.jpg' are the same file
# mv: 'IMG_1487.jpg' and 'IMG_1487.jpg' are the same file
# mv: 'IMG_1488.jpg' and 'IMG_1488.jpg' are the same file
# mv: 'IMG_1489.jpg' and 'IMG_1489.jpg' are the same file
# mv: 'IMG_1490.jpg' and 'IMG_1490.jpg' are the same file
# mv: 'IMG_1491.jpg' and 'IMG_1491.jpg' are the same file
# mv: 'IMG_1492.jpg' and 'IMG_1492.jpg' are the same file
# mv: 'IMG_1493.jpg' and 'IMG_1493.jpg' are the same file
# mv: 'IMG_1494.jpg' and 'IMG_1494.jpg' are the same file
# mv: 'IMG_1495.jpg' and 'IMG_1495.jpg' are the same file
# mv: 'IMG_1496.jpg' and 'IMG_1496.jpg' are the same file
# mv: 'IMG_1497.jpg' and 'IMG_1497.jpg' are the same file
# mv: 'IMG_1498.jpg' and 'IMG_1498.jpg' are the same file
# mv: 'IMG_1499.JPG' and 'IMG_1499.JPG' are the same file
# mv: 'IMG_1500.JPG' and 'IMG_1500.JPG' are the same file
# mv: 'IMG_1501.JPG' and 'IMG_1501.JPG' are the same file
# mv: 'IMG_1502.JPG' and 'IMG_1502.JPG' are the same file
# mv: 'IMG_1503.JPG' and 'IMG_1503.JPG' are the same file
# mv: 'IMG_1504.JPG' and 'IMG_1504.JPG' are the same file
# mv: 'IMG_1505.jpg' and 'IMG_1505.jpg' are the same file
# mv: 'IMG_1506.jpg' and 'IMG_1506.jpg' are the same file
# mv: 'IMG_1507.jpg' and 'IMG_1507.jpg' are the same file
# mv: 'IMG_1508.jpg' and 'IMG_1508.jpg' are the same file
# mv: 'IMG_1509.jpg' and 'IMG_1509.jpg' are the same file
# mv: 'IMG_1510.jpg' and 'IMG_1510.jpg' are the same file
# mv: 'IMG_1511.jpg' and 'IMG_1511.jpg' are the same file
# mv: 'IMG_1512.jpg' and 'IMG_1512.jpg' are the same file
# mv: 'IMG_1513.JPG' and 'IMG_1513.JPG' are the same file
# mv: 'IMG_1514.JPG' and 'IMG_1514.JPG' are the same file
# mv: 'IMG_1515.JPG' and 'IMG_1515.JPG' are the same file
# mv: 'IMG_1516.JPG' and 'IMG_1516.JPG' are the same file
# mv: 'IMG_1517.JPG' and 'IMG_1517.JPG' are the same file
# mv: 'IMG_1518.JPG' and 'IMG_1518.JPG' are the same file
# mv: 'IMG_1519.JPG' and 'IMG_1519.JPG' are the same file
# mv: 'IMG_1520.JPG' and 'IMG_1520.JPG' are the same file
# mv: 'IMG_1521.JPG' and 'IMG_1521.JPG' are the same file
# mv: 'IMG_1522.JPG' and 'IMG_1522.JPG' are the same file
# mv: 'IMG_1523.JPG' and 'IMG_1523.JPG' are the same file
# mv: 'IMG_1524.JPG' and 'IMG_1524.JPG' are the same file
# mv: 'IMG_1525.JPG' and 'IMG_1525.JPG' are the same file
# mv: 'IMG_1526.JPG' and 'IMG_1526.JPG' are the same file
# mv: 'IMG_1527.JPG' and 'IMG_1527.JPG' are the same file
# mv: 'IMG_1528.JPG' and 'IMG_1528.JPG' are the same file
# mv: 'IMG_1529.JPG' and 'IMG_1529.JPG' are the same file
# mv: 'IMG_1530.JPG' and 'IMG_1530.JPG' are the same file
# mv: 'IMG_1531.JPG' and 'IMG_1531.JPG' are the same file
# mv: 'IMG_1532.JPG' and 'IMG_1532.JPG' are the same file
# mv: 'IMG_1533.JPG' and 'IMG_1533.JPG' are the same file
# mv: 'IMG_1534.JPG' and 'IMG_1534.JPG' are the same file
# mv: 'IMG_1535.JPG' and 'IMG_1535.JPG' are the same file
# mv: 'IMG_1536.JPG' and 'IMG_1536.JPG' are the same file
# mv: 'IMG_1537.JPG' and 'IMG_1537.JPG' are the same file
# mv: 'IMG_1538.JPG' and 'IMG_1538.JPG' are the same file
# mv: 'IMG_1539.JPG' and 'IMG_1539.JPG' are the same file
# mv: 'IMG_1540.JPG' and 'IMG_1540.JPG' are the same file
# mv: 'IMG_1541.JPG' and 'IMG_1541.JPG' are the same file
# mv: 'IMG_1542.jpg' and 'IMG_1542.jpg' are the same file
# mv: 'IMG_1543.jpg' and 'IMG_1543.jpg' are the same file
# mv: 'IMG_1544.jpg' and 'IMG_1544.jpg' are the same file
# mv: 'IMG_1545.jpg' and 'IMG_1545.jpg' are the same file
# mv: 'IMG_1546.jpg' and 'IMG_1546.jpg' are the same file
# mv: 'IMG_1547.jpg' and 'IMG_1547.jpg' are the same file
# mv: 'IMG_1548.jpg' and 'IMG_1548.jpg' are the same file
# mv: 'IMG_1549.jpg' and 'IMG_1549.jpg' are the same file
# mv: 'IMG_1550.jpg' and 'IMG_1550.jpg' are the same file
# mv: 'IMG_1551.jpg' and 'IMG_1551.jpg' are the same file
# mv: 'IMG_1552.jpg' and 'IMG_1552.jpg' are the same file
# mv: 'IMG_1553.jpg' and 'IMG_1553.jpg' are the same file
# mv: 'IMG_1554.jpg' and 'IMG_1554.jpg' are the same file
# mv: 'IMG_1555.jpg' and 'IMG_1555.jpg' are the same file
# mv: 'IMG_1556.jpg' and 'IMG_1556.jpg' are the same file
# mv: 'IMG_1557(Edited).jpg' and 'IMG_1557(Edited).jpg' are the same file
# mv: 'IMG_1557.jpg' and 'IMG_1557.jpg' are the same file
# mv: 'IMG_1558.jpg' and 'IMG_1558.jpg' are the same file
# mv: 'IMG_1559.jpg' and 'IMG_1559.jpg' are the same file
# mv: 'IMG_1560.jpg' and 'IMG_1560.jpg' are the same file
# mv: 'IMG_1561.JPG' and 'IMG_1561.JPG' are the same file
# mv: 'IMG_1562.JPG' and 'IMG_1562.JPG' are the same file
# mv: 'IMG_1570.JPG' and 'IMG_1570.JPG' are the same file
# mv: 'IMG_1573.JPG' and 'IMG_1573.JPG' are the same file
# mv: 'IMG_1574.JPG' and 'IMG_1574.JPG' are the same file
# mv: 'IMG_1575.JPG' and 'IMG_1575.JPG' are the same file
# mv: 'IMG_1578.jpg' and 'IMG_1578.jpg' are the same file
# mv: 'IMG_1579.jpg' and 'IMG_1579.jpg' are the same file
# mv: 'IMG_1580.jpg' and 'IMG_1580.jpg' are the same file
# mv: 'IMG_1581.jpg' and 'IMG_1581.jpg' are the same file
# mv: 'IMG_1582.jpg' and 'IMG_1582.jpg' are the same file
# mv: 'IMG_1583.jpg' and 'IMG_1583.jpg' are the same file
# mv: 'IMG_1584.jpg' and 'IMG_1584.jpg' are the same file
# mv: 'IMG_1585.jpg' and 'IMG_1585.jpg' are the same file
# mv: 'IMG_1586.jpg' and 'IMG_1586.jpg' are the same file
# mv: 'IMG_1587(Edited).jpg' and 'IMG_1587(Edited).jpg' are the same file
# mv: 'IMG_1587.jpg' and 'IMG_1587.jpg' are the same file
# mv: 'IMG_1588(Edited).jpg' and 'IMG_1588(Edited).jpg' are the same file
# mv: 'IMG_1588.jpg' and 'IMG_1588.jpg' are the same file
# mv: 'IMG_1589(Edited).jpg' and 'IMG_1589(Edited).jpg' are the same file
# mv: 'IMG_1589.jpg' and 'IMG_1589.jpg' are the same file
# mv: 'IMG_1590(Edited).jpg' and 'IMG_1590(Edited).jpg' are the same file
# mv: 'IMG_1590.jpg' and 'IMG_1590.jpg' are the same file
# mv: 'IMG_1591.jpg' and 'IMG_1591.jpg' are the same file
# mv: 'IMG_1592.jpg' and 'IMG_1592.jpg' are the same file
# mv: 'IMG_1593.jpg' and 'IMG_1593.jpg' are the same file
# mv: 'IMG_1594.jpg' and 'IMG_1594.jpg' are the same file
# mv: 'IMG_1595.jpg' and 'IMG_1595.jpg' are the same file
# mv: 'IMG_1596.jpg' and 'IMG_1596.jpg' are the same file
# mv: 'IMG_1597.jpg' and 'IMG_1597.jpg' are the same file
# mv: 'IMG_1598.jpg' and 'IMG_1598.jpg' are the same file
# mv: 'IMG_1599.jpg' and 'IMG_1599.jpg' are the same file
# mv: 'IMG_1600.jpg' and 'IMG_1600.jpg' are the same file
# mv: 'IMG_1601.jpg' and 'IMG_1601.jpg' are the same file
# mv: 'IMG_1602.jpg' and 'IMG_1602.jpg' are the same file
# mv: 'IMG_1603.jpg' and 'IMG_1603.jpg' are the same file
# mv: 'IMG_1604.jpg' and 'IMG_1604.jpg' are the same file
# mv: 'IMG_1605.jpg' and 'IMG_1605.jpg' are the same file
# mv: 'IMG_1606.jpg' and 'IMG_1606.jpg' are the same file
# mv: 'IMG_1607.jpg' and 'IMG_1607.jpg' are the same file
# mv: 'IMG_1608.jpg' and 'IMG_1608.jpg' are the same file
# mv: 'IMG_1609.jpg' and 'IMG_1609.jpg' are the same file
# mv: 'IMG_1610.jpg' and 'IMG_1610.jpg' are the same file
# mv: 'IMG_1611.jpg' and 'IMG_1611.jpg' are the same file
# mv: 'IMG_1612.jpg' and 'IMG_1612.jpg' are the same file
# mv: 'IMG_1613.jpg' and 'IMG_1613.jpg' are the same file
# mv: 'IMG_1614.jpg' and 'IMG_1614.jpg' are the same file
# mv: 'IMG_1615.jpg' and 'IMG_1615.jpg' are the same file
# mv: 'IMG_1631.jpg' and 'IMG_1631.jpg' are the same file
# mv: 'IMG_1632.jpg' and 'IMG_1632.jpg' are the same file
# mv: 'IMG_1633_HEVC.MOV' and 'IMG_1633_HEVC.MOV' are the same file
# mv: 'IMG_1634_HEVC.MOV' and 'IMG_1634_HEVC.MOV' are the same file
# mv: 'IMG_1635.jpg' and 'IMG_1635.jpg' are the same file
# mv: 'IMG_1636.jpg' and 'IMG_1636.jpg' are the same file
# mv: 'IMG_1637.jpg' and 'IMG_1637.jpg' are the same file
# mv: 'IMG_1638.jpg' and 'IMG_1638.jpg' are the same file
# mv: 'IMG_1639.jpg' and 'IMG_1639.jpg' are the same file
# mv: 'IMG_1640.jpg' and 'IMG_1640.jpg' are the same file
# mv: 'IMG_1641.jpg' and 'IMG_1641.jpg' are the same file
# mv: 'IMG_1642.jpg' and 'IMG_1642.jpg' are the same file
# mv: 'IMG_1643.jpg' and 'IMG_1643.jpg' are the same file
# mv: 'IMG_1644.jpg' and 'IMG_1644.jpg' are the same file
# mv: 'IMG_1645.jpg' and 'IMG_1645.jpg' are the same file
# mv: 'IMG_1646.jpg' and 'IMG_1646.jpg' are the same file
# mv: 'IMG_1647.jpg' and 'IMG_1647.jpg' are the same file
# mv: 'IMG_1648.jpg' and 'IMG_1648.jpg' are the same file
# mv: 'IMG_1649.jpg' and 'IMG_1649.jpg' are the same file
# mv: 'IMG_1674.jpg' and 'IMG_1674.jpg' are the same file
# mv: 'IMG_1675.jpg' and 'IMG_1675.jpg' are the same file
# mv: 'IMG_1676.jpg' and 'IMG_1676.jpg' are the same file
# mv: 'IMG_1677.jpg' and 'IMG_1677.jpg' are the same file
# mv: 'IMG_1678.jpg' and 'IMG_1678.jpg' are the same file
# mv: 'IMG_1679.JPG' and 'IMG_1679.JPG' are the same file
# mv: 'IMG_1680.JPG' and 'IMG_1680.JPG' are the same file
# mv: 'IMG_1681.jpg' and 'IMG_1681.jpg' are the same file
# mv: 'IMG_1682.jpg' and 'IMG_1682.jpg' are the same file
# mv: 'IMG_1683.jpg' and 'IMG_1683.jpg' are the same file
# mv: 'IMG_1684.jpg' and 'IMG_1684.jpg' are the same file
# mv: 'IMG_1685.jpg' and 'IMG_1685.jpg' are the same file
# mv: 'IMG_1686.JPG' and 'IMG_1686.JPG' are the same file
# mv: 'IMG_1687.JPG' and 'IMG_1687.JPG' are the same file
# mv: 'IMG_1688.JPG' and 'IMG_1688.JPG' are the same file
# mv: 'IMG_1689.JPG' and 'IMG_1689.JPG' are the same file
# mv: 'IMG_1690.JPG' and 'IMG_1690.JPG' are the same file
# mv: 'IMG_1691.jpg' and 'IMG_1691.jpg' are the same file
# mv: 'IMG_1692.jpg' and 'IMG_1692.jpg' are the same file
# mv: 'IMG_1693.jpg' and 'IMG_1693.jpg' are the same file
# mv: 'IMG_1694.jpg' and 'IMG_1694.jpg' are the same file
# mv: 'IMG_1695.jpg' and 'IMG_1695.jpg' are the same file
# mv: 'IMG_1696.jpg' and 'IMG_1696.jpg' are the same file
# mv: 'IMG_1697.jpg' and 'IMG_1697.jpg' are the same file
# mv: 'IMG_1698.jpg' and 'IMG_1698.jpg' are the same file
# mv: 'IMG_1699.jpg' and 'IMG_1699.jpg' are the same file
# mv: 'IMG_1700.jpg' and 'IMG_1700.jpg' are the same file
# mv: 'IMG_1701.jpg' and 'IMG_1701.jpg' are the same file
# mv: 'IMG_1702.jpg' and 'IMG_1702.jpg' are the same file
# mv: 'IMG_1703.jpg' and 'IMG_1703.jpg' are the same file
# mv: 'IMG_1704.jpg' and 'IMG_1704.jpg' are the same file
# mv: 'IMG_1705.jpg' and 'IMG_1705.jpg' are the same file
# mv: 'IMG_1706.jpg' and 'IMG_1706.jpg' are the same file
# mv: 'IMG_1707.jpg' and 'IMG_1707.jpg' are the same file
# mv: 'IMG_1710.jpg' and 'IMG_1710.jpg' are the same file
# mv: 'IMG_1711.jpg' and 'IMG_1711.jpg' are the same file
# mv: 'IMG_1712.jpg' and 'IMG_1712.jpg' are the same file
# mv: 'IMG_1713.jpg' and 'IMG_1713.jpg' are the same file
# mv: 'IMG_1714.jpg' and 'IMG_1714.jpg' are the same file
# mv: 'IMG_1715.jpg' and 'IMG_1715.jpg' are the same file
# mv: 'IMG_1716.jpg' and 'IMG_1716.jpg' are the same file
# mv: 'IMG_1717.jpg' and 'IMG_1717.jpg' are the same file
# mv: 'IMG_1718.jpg' and 'IMG_1718.jpg' are the same file
# mv: 'IMG_1719.jpg' and 'IMG_1719.jpg' are the same file
# mv: 'IMG_1720.jpg' and 'IMG_1720.jpg' are the same file
# mv: 'IMG_1721.jpg' and 'IMG_1721.jpg' are the same file
# mv: 'IMG_1722.jpg' and 'IMG_1722.jpg' are the same file
# mv: 'IMG_1723.jpg' and 'IMG_1723.jpg' are the same file
# mv: 'IMG_1724.jpg' and 'IMG_1724.jpg' are the same file
# mv: 'IMG_1725.jpg' and 'IMG_1725.jpg' are the same file
# mv: 'IMG_1726.jpg' and 'IMG_1726.jpg' are the same file
# mv: 'IMG_1727.jpg' and 'IMG_1727.jpg' are the same file
# mv: 'IMG_1728.jpg' and 'IMG_1728.jpg' are the same file
# mv: 'IMG_1729.jpg' and 'IMG_1729.jpg' are the same file
# mv: 'IMG_7179.PNG' and 'IMG_7179.PNG' are the same file
# mv: 'IMG_7180.PNG' and 'IMG_7180.PNG' are the same file
# mv: 'IMG_7181.PNG' and 'IMG_7181.PNG' are the same file
# mv: 'IMG_7182.PNG' and 'IMG_7182.PNG' are the same file
# mv: 'IMG_7183.PNG' and 'IMG_7183.PNG' are the same file
# mv: 'IMG_7184.PNG' and 'IMG_7184.PNG' are the same file
# mv: 'IMG_7185.PNG' and 'IMG_7185.PNG' are the same file
# mv: 'IMG_7186.PNG' and 'IMG_7186.PNG' are the same file
# mv: 'a0a97dd2-8a08-4f3f-a640-39c591075cbf.jpg' and 'a0a97dd2-8a08-4f3f-a640-39c591075cbf.jpg' are the same file
# mv: 'a5e6f367-f47d-4117-9ffa-77afede120bc.jpg' and 'a5e6f367-f47d-4117-9ffa-77afede120bc.jpg' are the same file
# mv: 'ab9ebabc-5661-4d7e-8215-748a89c87616.jpg' and 'ab9ebabc-5661-4d7e-8215-748a89c87616.jpg' are the same file
# mv: 'b0543a06-fe20-46be-ab09-65b1e0c3c6c2.jpg' and 'b0543a06-fe20-46be-ab09-65b1e0c3c6c2.jpg' are the same file
# mv: 'b8861b8d-a9bf-440d-bee7-26038763bb1b.jpg' and 'b8861b8d-a9bf-440d-bee7-26038763bb1b.jpg' are the same file
# mv: 'bba1ee1c-cbed-40fd-baaa-815d53ad22b9.jpg' and 'bba1ee1c-cbed-40fd-baaa-815d53ad22b9.jpg' are the same file
# mv: 'c363bb40-95d4-42bf-9621-cd47764c4979.jpg' and 'c363bb40-95d4-42bf-9621-cd47764c4979.jpg' are the same file
# mv: 'df3dff3d-618b-4449-aceb-f021192fec65.jpg' and 'df3dff3d-618b-4449-aceb-f021192fec65.jpg' are the same file
# mv: 'f62ef496-7f96-4ecd-bbf1-7b67a6c5fcba.jpg' and 'f62ef496-7f96-4ecd-bbf1-7b67a6c5fcba.jpg' are the same file
# mv: 'f62fe6b5-4fab-45db-8c8b-d380287835dd.jpg' and 'f62fe6b5-4fab-45db-8c8b-d380287835dd.jpg' are the same file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-31-66632a39b76a> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/TrumpHotel\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/TrumpHotel\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/Gaeltacht
# for f in * ; do mv "$f" `echo $f | tr ' ' '_'`; done
# Out:
# mv: 'IMG_0693.PNG' and 'IMG_0693.PNG' are the same file
# mv: 'IMG_0696(1).PNG' and 'IMG_0696(1).PNG' are the same file
# mv: 'IMG_1766.JPG' and 'IMG_1766.JPG' are the same file
# mv: 'IMG_1780.JPG' and 'IMG_1780.JPG' are the same file
# mv: 'IMG_1781.JPG' and 'IMG_1781.JPG' are the same file
# mv: 'IMG_1788.JPG' and 'IMG_1788.JPG' are the same file
# mv: 'IMG_1794.JPG' and 'IMG_1794.JPG' are the same file
# mv: 'IMG_1795.JPG' and 'IMG_1795.JPG' are the same file
# mv: 'IMG_1796.JPG' and 'IMG_1796.JPG' are the same file
# mv: 'IMG_1797.JPG' and 'IMG_1797.JPG' are the same file
# mv: 'IMG_1800.JPG' and 'IMG_1800.JPG' are the same file
# mv: 'IMG_1804.JPG' and 'IMG_1804.JPG' are the same file
# mv: 'IMG_1808.JPG' and 'IMG_1808.JPG' are the same file
# mv: 'IMG_1809.MOV' and 'IMG_1809.MOV' are the same file
# mv: 'IMG_1810.JPG' and 'IMG_1810.JPG' are the same file
# mv: 'IMG_1812.JPG' and 'IMG_1812.JPG' are the same file
# mv: 'IMG_1813.JPG' and 'IMG_1813.JPG' are the same file
# mv: 'IMG_1815.JPG' and 'IMG_1815.JPG' are the same file
# mv: 'IMG_1825.JPG' and 'IMG_1825.JPG' are the same file
# mv: 'IMG_1830.JPG' and 'IMG_1830.JPG' are the same file
# mv: 'IMG_1831.JPG' and 'IMG_1831.JPG' are the same file
# mv: 'IMG_1832.JPG' and 'IMG_1832.JPG' are the same file
# mv: 'IMG_1835.PNG' and 'IMG_1835.PNG' are the same file
# mv: 'IMG_1838.JPG' and 'IMG_1838.JPG' are the same file
# mv: 'IMG_1839.JPG' and 'IMG_1839.JPG' are the same file
# mv: 'IMG_2171.JPG' and 'IMG_2171.JPG' are the same file
# mv: 'IMG_2172.JPG' and 'IMG_2172.JPG' are the same file
# mv: 'IMG_2173.JPG' and 'IMG_2173.JPG' are the same file
# mv: 'IMG_2175.JPG' and 'IMG_2175.JPG' are the same file
# mv: 'IMG_2180.JPG' and 'IMG_2180.JPG' are the same file
# mv: 'IMG_2188.JPG' and 'IMG_2188.JPG' are the same file
# mv: 'IMG_2192.JPG' and 'IMG_2192.JPG' are the same file
# mv: 'IMG_2194.JPG' and 'IMG_2194.JPG' are the same file
# mv: 'IMG_2195.JPG' and 'IMG_2195.JPG' are the same file
# mv: 'IMG_2196.JPG' and 'IMG_2196.JPG' are the same file
# mv: 'IMG_2197.JPG' and 'IMG_2197.JPG' are the same file
# mv: 'IMG_2198.JPG' and 'IMG_2198.JPG' are the same file
# mv: 'IMG_2202.JPG' and 'IMG_2202.JPG' are the same file
# mv: 'IMG_2218.JPG' and 'IMG_2218.JPG' are the same file
# mv: 'IMG_2219.JPG' and 'IMG_2219.JPG' are the same file
# mv: 'IMG_2220.JPG' and 'IMG_2220.JPG' are the same file
# mv: 'IMG_2221.JPG' and 'IMG_2221.JPG' are the same file
# mv: 'IMG_2222.JPG' and 'IMG_2222.JPG' are the same file
# mv: 'IMG_2224.JPG' and 'IMG_2224.JPG' are the same file
# mv: 'IMG_2227.JPG' and 'IMG_2227.JPG' are the same file
# mv: 'IMG_2233.JPG' and 'IMG_2233.JPG' are the same file
# mv: 'IMG_2236.JPG' and 'IMG_2236.JPG' are the same file
# mv: 'IMG_2238.JPG' and 'IMG_2238.JPG' are the same file
# mv: 'IMG_2239.JPG' and 'IMG_2239.JPG' are the same file
# mv: 'IMG_2240.JPG' and 'IMG_2240.JPG' are the same file
# mv: 'IMG_2242.JPG' and 'IMG_2242.JPG' are the same file
# mv: 'IMG_2244.JPG' and 'IMG_2244.JPG' are the same file
# mv: 'IMG_2246.JPG' and 'IMG_2246.JPG' are the same file
# mv: 'IMG_2247.JPG' and 'IMG_2247.JPG' are the same file
# mv: 'IMG_2252.JPG' and 'IMG_2252.JPG' are the same file
# mv: 'IMG_2254.JPG' and 'IMG_2254.JPG' are the same file
# mv: 'IMG_2255.JPG' and 'IMG_2255.JPG' are the same file
# mv: 'IMG_2256.JPG' and 'IMG_2256.JPG' are the same file
# mv: 'IMG_2259.JPG' and 'IMG_2259.JPG' are the same file
# mv: 'IMG_2260.JPG' and 'IMG_2260.JPG' are the same file
# mv: 'IMG_2262.JPG' and 'IMG_2262.JPG' are the same file
# mv: 'IMG_2263.JPG' and 'IMG_2263.JPG' are the same file
# mv: 'IMG_2274.JPG' and 'IMG_2274.JPG' are the same file
# mv: 'IMG_2357.JPG' and 'IMG_2357.JPG' are the same file
# mv: 'IMG_2402.JPG' and 'IMG_2402.JPG' are the same file
# mv: 'IMG_2403.JPG' and 'IMG_2403.JPG' are the same file
# mv: 'IMG_2404.JPG' and 'IMG_2404.JPG' are the same file
# mv: 'IMG_2406.JPG' and 'IMG_2406.JPG' are the same file
# mv: 'IMG_2408.JPG' and 'IMG_2408.JPG' are the same file
# mv: 'IMG_2409.JPG' and 'IMG_2409.JPG' are the same file
# mv: 'IMG_2410.JPG' and 'IMG_2410.JPG' are the same file
# mv: 'IMG_2411.JPG' and 'IMG_2411.JPG' are the same file
# mv: 'IMG_2412.JPG' and 'IMG_2412.JPG' are the same file
# mv: 'IMG_2413.JPG' and 'IMG_2413.JPG' are the same file
# mv: 'IMG_2415.JPG' and 'IMG_2415.JPG' are the same file
# mv: 'IMG_8083.JPG' and 'IMG_8083.JPG' are the same file
# mv: 'IMG_8111.JPG' and 'IMG_8111.JPG' are the same file
# mv: 'IMG_8112.JPG' and 'IMG_8112.JPG' are the same file
# mv: 'IMG_8113.JPG' and 'IMG_8113.JPG' are the same file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-32-2a8e8b4868dc> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/Gaeltacht\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/Gaeltacht\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/DennisGraduation
# for f in * ; do mv "$f" `echo $f | tr ' ' '_'`; done
# Out:
# mv: '277b29ff-06fb-4a8d-9665-b5fcc324286f.jpg' and '277b29ff-06fb-4a8d-9665-b5fcc324286f.jpg' are the same file
# mv: '3cd63033-a939-486c-bdf2-78140aba666d.jpg' and '3cd63033-a939-486c-bdf2-78140aba666d.jpg' are the same file
# mv: '3d70ef74-0c1c-4dd0-bb9f-68d53c2fe6ca.jpg' and '3d70ef74-0c1c-4dd0-bb9f-68d53c2fe6ca.jpg' are the same file
# mv: '47a2e173-dee1-4364-861b-a7397a80f044.jpg' and '47a2e173-dee1-4364-861b-a7397a80f044.jpg' are the same file
# mv: '58130388-7e4e-4e45-8208-199add2a02d7.jpg' and '58130388-7e4e-4e45-8208-199add2a02d7.jpg' are the same file
# mv: '5b791f4d-21b1-442b-839d-74655f1bd1f5.jpg' and '5b791f4d-21b1-442b-839d-74655f1bd1f5.jpg' are the same file
# mv: '635fe770-29fb-4d81-9c75-eddfaab948da.jpg' and '635fe770-29fb-4d81-9c75-eddfaab948da.jpg' are the same file
# mv: '6747cbb5-6158-4a11-aa7a-6f83b7ba2b60.jpg' and '6747cbb5-6158-4a11-aa7a-6f83b7ba2b60.jpg' are the same file
# mv: '86176e58-3aac-4123-9fa4-6e432554b39d.jpg' and '86176e58-3aac-4123-9fa4-6e432554b39d.jpg' are the same file
# mv: 'IMG_4723_HEVC.MOV' and 'IMG_4723_HEVC.MOV' are the same file
# mv: 'IMG_4724(Edited).jpg' and 'IMG_4724(Edited).jpg' are the same file
# mv: 'IMG_4724.jpg' and 'IMG_4724.jpg' are the same file
# mv: 'IMG_4725_HEVC.MOV' and 'IMG_4725_HEVC.MOV' are the same file
# mv: 'IMG_4726.jpg' and 'IMG_4726.jpg' are the same file
# mv: 'IMG_4727.jpg' and 'IMG_4727.jpg' are the same file
# mv: 'IMG_4728.jpg' and 'IMG_4728.jpg' are the same file
# mv: 'IMG_4729(Edited).jpg' and 'IMG_4729(Edited).jpg' are the same file
# mv: 'IMG_4729.jpg' and 'IMG_4729.jpg' are the same file
# mv: 'IMG_4730(Edited).jpg' and 'IMG_4730(Edited).jpg' are the same file
# mv: 'IMG_4730.jpg' and 'IMG_4730.jpg' are the same file
# mv: 'IMG_4731.jpg' and 'IMG_4731.jpg' are the same file
# mv: 'IMG_4732.jpg' and 'IMG_4732.jpg' are the same file
# mv: 'IMG_4733.jpg' and 'IMG_4733.jpg' are the same file
# mv: 'IMG_4734.jpg' and 'IMG_4734.jpg' are the same file
# mv: 'IMG_4735_HEVC.MOV' and 'IMG_4735_HEVC.MOV' are the same file
# mv: 'IMG_4736.jpg' and 'IMG_4736.jpg' are the same file
# mv: 'IMG_4737.jpg' and 'IMG_4737.jpg' are the same file
# mv: 'IMG_4741.jpg' and 'IMG_4741.jpg' are the same file
# mv: 'IMG_4742.jpg' and 'IMG_4742.jpg' are the same file
# mv: 'IMG_4743.jpg' and 'IMG_4743.jpg' are the same file
# mv: 'IMG_4744.jpg' and 'IMG_4744.jpg' are the same file
# mv: 'IMG_4745.jpg' and 'IMG_4745.jpg' are the same file
# mv: 'IMG_4746.jpg' and 'IMG_4746.jpg' are the same file
# mv: 'IMG_4748.jpg' and 'IMG_4748.jpg' are the same file
# mv: 'IMG_4750.jpg' and 'IMG_4750.jpg' are the same file
# mv: 'IMG_4751.jpg' and 'IMG_4751.jpg' are the same file
# mv: 'IMG_4752.jpg' and 'IMG_4752.jpg' are the same file
# mv: 'IMG_4753.jpg' and 'IMG_4753.jpg' are the same file
# mv: 'IMG_4757.jpg' and 'IMG_4757.jpg' are the same file
# mv: 'IMG_4758.jpg' and 'IMG_4758.jpg' are the same file
# mv: 'IMG_6654.JPG' and 'IMG_6654.JPG' are the same file
# mv: 'b60d17ca-a7e5-4efa-8858-9198b112b18e.jpg' and 'b60d17ca-a7e5-4efa-8858-9198b112b18e.jpg' are the same file
# mv: 'e5b88563-0145-4861-825f-a39c4cd488f8.jpg' and 'e5b88563-0145-4861-825f-a39c4cd488f8.jpg' are the same file
# mv: 'eefc466e-d343-402f-b895-aba7bdc4fe15.jpg' and 'eefc466e-d343-402f-b895-aba7bdc4fe15.jpg' are the same file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-33-64df56dd4331> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/DennisGraduation\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/DennisGraduation\nfor f in * ; do mv "$f" `echo $f | tr \' \' \'_\'`; done\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2018
# ls -l |awk '{ if ($8 == "2016") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2016.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2018
# ls -l |awk '{ if ($8 == "2017") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2017.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2018
# ls -l |awk '{ if ($8 == "2019") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2019.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2018
# mv $(find . | grep -F -f 2016.txt) ../2016/
# mv $(find . | grep -F -f 2017.txt) ../2017/
# mv $(find . | grep -F -f 2019.txt) ../2019/

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2019
# ls -l |awk '{ if ($8 == "2015") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2015.txt
# ls -l |awk '{ if ($8 == "2016") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2016.txt
# ls -l |awk '{ if ($8 == "2017") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2017.txt
# ls -l |awk '{ if ($8 == "2018") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2018.txt
# ls -l |awk '{ if ($8 == "2020") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2020.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2019
# mv $(find . | grep -F -f 2015.txt) ../2015/
# mv $(find . | grep -F -f 2016.txt) ../2016/
# mv $(find . | grep -F -f 2017.txt) ../2017/
# mv $(find . | grep -F -f 2018.txt) ../2018/
# mv $(find . | grep -F -f 2020.txt) ../2020/
# Out:
# mv: missing destination file operand after '../2015/.'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2016/.'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2017/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2018/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2020/.'
# Try 'mv --help' for more information.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-40-1a3aa4a30f89> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/2019\nmv $(find . | grep -F -f 2015.txt) ../2015/.\nmv $(find . | grep -F -f 2016.txt) ../2016/.\nmv $(find . | grep -F -f 2017.txt) ../2017/\nmv $(find . | grep -F -f 2018.txt) ../2018/\nmv $(find . | grep -F -f 2020.txt) ../2020/.\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/2019\nmv $(find . | grep -F -f 2015.txt) ../2015/.\nmv $(find . | grep -F -f 2016.txt) ../2016/.\nmv $(find . | grep -F -f 2017.txt) ../2017/\nmv $(find . | grep -F -f 2018.txt) ../2018/\nmv $(find . | grep -F -f 2020.txt) ../2020/.\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2020
# ls -l |awk '{ if ($8 == "2015") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2015.txt
# ls -l |awk '{ if ($8 == "2016") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2016.txt
# ls -l |awk '{ if ($8 == "2017") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2017.txt
# ls -l |awk '{ if ($8 == "2018") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2018.txt
# ls -l |awk '{ if ($8 == "2019") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2019.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2020
# mv $(find . | grep -F -f 2015.txt) ../2015/
# mv $(find . | grep -F -f 2016.txt) ../2016/
# mv $(find . | grep -F -f 2017.txt) ../2017/
# mv $(find . | grep -F -f 2018.txt) ../2018/
# mv $(find . | grep -F -f 2019.txt) ../2019/
# Out:
# mv: missing destination file operand after '../2015/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2016/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2017/'
# Try 'mv --help' for more information.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2017
# ls -l |awk '{ if ($8 == "2015") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2015.txt
# ls -l |awk '{ if ($8 == "2016") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2016.txt
# ls -l |awk '{ if ($8 == "2020") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2020.txt
# ls -l |awk '{ if ($8 == "2018") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2018.txt
# ls -l |awk '{ if ($8 == "2019") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2019.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2017
# mv $(find . | grep -F -f 2015.txt) ../2015/
# mv $(find . | grep -F -f 2016.txt) ../2016/
# mv $(find . | grep -F -f 2020.txt) ../2020/
# mv $(find . | grep -F -f 2018.txt) ../2018/
# mv $(find . | grep -F -f 2019.txt) ../2019/
# Out:
# mv: missing destination file operand after '../2020/'
# Try 'mv --help' for more information.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2016
# ls -l |awk '{ if ($8 == "2015") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2015.txt
# ls -l |awk '{ if ($8 == "2017") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2017.txt
# ls -l |awk '{ if ($8 == "2020") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2020.txt
# ls -l |awk '{ if ($8 == "2018") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2018.txt
# ls -l |awk '{ if ($8 == "2019") print $FILENAME }'| awk '{$1=$2=$3=$4=$5=$6=$7=$8=""; print $0}' | sed -e 's/^[ \t]*//' > 2019.txt

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2016
# mv $(find . | grep -F -f 2015.txt) ../2015/
# mv $(find . | grep -F -f 2017.txt) ../2017/
# mv $(find . | grep -F -f 2020.txt) ../2020/
# mv $(find . | grep -F -f 2018.txt) ../2018/
# mv $(find . | grep -F -f 2019.txt) ../2019/
# Out:
# mv: missing destination file operand after '../2020/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '../2019/'
# Try 'mv --help' for more information.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-46-0c9da5fe9181> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/2016\nmv $(find . | grep -F -f 2015.txt) ../2015/\nmv $(find . | grep -F -f 2017.txt) ../2017/\nmv $(find . | grep -F -f 2020.txt) ../2020/\nmv $(find . | grep -F -f 2018.txt) ../2018/\nmv $(find . | grep -F -f 2019.txt) ../2019/\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/2016\nmv $(find . | grep -F -f 2015.txt) ../2015/\nmv $(find . | grep -F -f 2017.txt) ../2017/\nmv $(find . | grep -F -f 2020.txt) ../2020/\nmv $(find . | grep -F -f 2018.txt) ../2018/\nmv $(find . | grep -F -f 2019.txt) ../2019/\n'' returned non-zero exit status 1.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2017
# mkdir Videos
# mv *.MOV Videos/.
# Out:
# mkdir: cannot create directory â€˜Videosâ€™: File exists

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2018
# mv *.MOV Videos/.

# %%
# %%bash
# cd "Pictures/iCloud Photos"/Downloads/2019
# mv *.MOV Videos/.

# %%
# Out:
# ls: cannot access '*.mp4': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-63-49fedb4f3c55> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd "Pictures/iCloud Photos"/Downloads/2020\nls *.mp4\n')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <C:\Users\lyaso\Anaconda3\lib\site-packages\decorator.py:decorator-gen-111> in shebang(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd "Pictures/iCloud Photos"/Downloads/2020\nls *.mp4\n'' returned non-zero exit status 2.
